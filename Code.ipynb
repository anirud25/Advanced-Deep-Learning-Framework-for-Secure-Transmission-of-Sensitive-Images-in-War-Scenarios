# %%
from PIL import Image
import numpy as np

def message_to_bin(message):
    binary = ''.join(format(ord(i), '08b') for i in message)
    return binary

def modify_pixel(pixel, binary_message, index):
    if index < len(binary_message):
        pixel = (pixel & ~1) | int(binary_message[index])
    return pixel

def encode_image(img_path, message):
    img = Image.open(img_path)
    binary_message = message_to_bin(message) + '11111111'  # Delimiter to indicate end of message
    pixels = np.array(img)

    index = 0
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            for k in range(3):  # Iterate over RGB channels
                if index < len(binary_message):
                    pixels[i, j, k] = modify_pixel(pixels[i, j, k], binary_message, index)
                    index += 1

    encoded_img = Image.fromarray(pixels)
    return encoded_img

# Example usage:
encoded_image = encode_image('input_image.png', 'YourSecretCode123')
encoded_image.save('encoded_image.png')

# %%
def decode_image(img_path):
    img = Image.open(img_path)
    pixels = np.array(img)11
    binary_message = ''
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            for k in range(3):
                binary_message += str(pixels[i, j, k] & 1)
                if binary_message[-8:] == '11111111':  # Check for delimiter
                    return ''.join(chr(int(binary_message[i:i+8], 2)) for i in range(0, len(binary_message)-8, 8))
    return None

# Example usage:
decoded_message = decode_image('encoded_image.png')
print(decoded_message)
# Out:
# YourSecretCode123

# %%
from PIL import Image
import numpy as np

def add_noise(img, mean=0, var=0.01):
    """ Add Gaussian noise to an image. """
    row, col, ch = img.shape
    sigma = var**0.5
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    gauss = gauss.reshape(row, col, ch)
    noisy = img + gauss
    return np.clip(noisy, 0, 255).astype(np.uint8)

def crop_image(img, start_x, start_y, end_x, end_y):
    """ Crop an image. """
    return img[start_y:end_y, start_x:end_x]

def rotate_image(img, angle):
    """ Rotate an image. """
    return img.rotate(angle, expand=True)

def tamper_image(img_path, save_path='tampered_image.png'):
    img = Image.open(img_path)
    img = np.array(img)

    # Optionally add noise
    img = add_noise(img)

    # Optionally crop the image (specify the crop area)
    #img = crop_image(img, 50, 50, 200, 200)  # Adjust these values based on your image dimensions

    # Convert back to PIL Image to rotate
    img = Image.fromarray(img)
    #img = rotate_image(img, 45)  # Rotate by 45 degrees

    # Save the tampered image
    img.save(save_path)
    return save_path

# Example usage:
tampered_image_path = tamper_image('input_image.png')
print("Tampered image saved to:", tampered_image_path)
# Out:
# Tampered image saved to: tampered_image.png

# %% [markdown]
# ### ResNet50

# %%
from PIL import Image
import numpy as np

def message_to_bin(message):
    binary = ''.join(format(ord(i), '08b') for i in message)
    return binary

def modify_pixel(pixel, binary_message, index):
    if index < len(binary_message):
        pixel = (pixel & ~1) | int(binary_message[index])
    return pixel

def encode_image(img_path, message, save_path='encoded_image.png'):
    img = Image.open(img_path)
    binary_message = message_to_bin(message) + '11111111'  # Delimiter to indicate end of message
    pixels = np.array(img)

    index = 0
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            for k in range(3):  # Iterate over RGB channels
                if index < len(binary_message):
                    pixels[i, j, k] = modify_pixel(pixels[i, j, k], binary_message, index)
                    index += 1

    encoded_img = Image.fromarray(pixels)
    encoded_img.save(save_path)
    return save_path


import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'encoded' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained model and modify it for binary classification
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1, Loss: 0.9581713080406189
# Epoch 2, Loss: 0.8205904364585876
# Epoch 3, Loss: 0.6710663437843323
# Epoch 4, Loss: 0.6272410154342651
# Epoch 5, Loss: 0.6771294474601746
# Epoch 6, Loss: 0.7419540882110596
# Epoch 7, Loss: 0.7706840634346008
# Epoch 8, Loss: 0.7510538101196289
# Epoch 9, Loss: 0.6946001052856445
# Epoch 10, Loss: 0.6298009753227234
# Accuracy: 66.66666666666667%

# %%
predicted
# Out:
# tensor([0, 0, 0])

# %% [markdown]
# ### VGG16

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'encoded' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained VGG16 model and modify it for binary classification
model = models.vgg16(pretrained=True)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 2)  # Modify the classifier layer

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 5
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# Epoch 1, Loss: 0.4455904960632324
# Epoch 2, Loss: 0.5198726058006287
# Epoch 3, Loss: 0.5281772613525391
# Epoch 4, Loss: 0.9445035457611084
# Epoch 5, Loss: 0.7109470367431641
# Accuracy: 100.0%

# %%
labels
# Out:
# tensor([0, 0, 1])

# %% [markdown]
# ### Inception_v3

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'encoded' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations for Inception v3
transform = transforms.Compose([
    transforms.Resize(299),  # Resize so the smallest side is 299 pixels
    transforms.CenterCrop(299),  # Crop to 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained Inception v3 model and modify it for binary classification
model = models.inception_v3(pretrained=True)
# Handle the auxiliary net
aux_in_features = model.AuxLogits.fc.in_features
model.AuxLogits.fc = nn.Linear(aux_in_features, 2)
# Handle the primary net
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 5
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs, aux_outputs = model(inputs)  # Inception model outputs main and auxiliary outputs
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        loss = loss1 + 0.4 * loss2  # Combine losses
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)  # Ignore auxiliary outputs during evaluation
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# Epoch 1, Loss: 0.9869362115859985
# Epoch 2, Loss: 0.9992379546165466
# Epoch 3, Loss: 0.8710058331489563
# Epoch 4, Loss: 0.8620637059211731
# Epoch 5, Loss: 0.7637868523597717
# Accuracy: 66.66666666666667%

# %%
labels
# Out:
# tensor([0, 1, 0])

# %% [markdown]
# #### HIDDEN: 50 images each

# %%
import os
import random
import shutil

# Define source directories
image_dir = '/content/dataset/ukraine_war_resized'
tampered_dir = '/content/dataset/ukraine_war_tampered'

# Define destination directory
destination_dir = '/content/dataset/final_100'

# Function to copy a subset of images from source directory to destination directory
def copy_subset_images(source_dir, dest_dir, num_images):
    # Get a list of all files in the source directory
    files = os.listdir(source_dir)
    # Shuffle the list
    random.shuffle(files)
    # Take a subset of the shuffled list
    subset = files[:num_images]
    # Copy each file from the subset to the destination directory
    for filename in subset:
        shutil.copy(os.path.join(source_dir, filename), dest_dir)

# Copy subset of original images
copy_subset_images(image_dir, destination_dir, 50)

# Copy subset of tampered images
copy_subset_images(tampered_dir, destination_dir, 50)

print("Subset of 50 original and 50 tampered images copied successfully to", destination_dir)

# Get the list of files in the directory
files = os.listdir(destination_dir)

# Count the number of files with "tampered" in their name
tampered_count = sum('tampered' in filename for filename in files)

print("Number of files with 'tampered' in their name:", tampered_count)
# Out:
# Subset of 50 original and 50 tampered images copied successfully to /content/dataset/final_100
# Number of files with 'tampered' in their name: 50

# %%
copy_to_drive('/content/dataset/final_100','/content/drive/MyDrive/Courses/Sem 2/DL/final_100')
# Out:
# Folder copied successfully to Google Drive.

# %% [markdown]
# ### Entire Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gdown
import zipfile
import os

# Define the URL of the ZIP file
zip_url = 'https://drive.google.com/uc?id=1XBrjRp_1ssW_QqmrGbO3kO6vQm8tlUck'

# Define the directory where you want to extract the ZIP file
extracted_dir_path = '/content/dataset/ukraine_war'

# Create the directory if it doesn't exist
os.makedirs(extracted_dir_path, exist_ok=True)

# Download the ZIP file
zip_file_path = os.path.join(extracted_dir_path, 'ukraine_war.zip')
gdown.download(zip_url, zip_file_path, quiet=False)

# Extract the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_dir_path)

# Check the contents of the extracted directory
extracted_files = os.listdir(extracted_dir_path)
print("Contents of the extracted directory:")
print(extracted_files)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1XBrjRp_1ssW_QqmrGbO3kO6vQm8tlUck
# From (redirected): https://drive.google.com/uc?id=1XBrjRp_1ssW_QqmrGbO3kO6vQm8tlUck&confirm=t&uuid=e0662617-a24c-4935-91bb-0008d692052a
# To: /content/dataset/ukraine_war/ukraine_war.zip
# 100%|██████████| 1.58G/1.58G [00:27<00:00, 56.4MB/s]
# Contents of the extracted directory:
# ['ukraine_war.zip', 'ukraine_war']

# %%
import os
import cv2

def convert_and_resize_images(image_dir, output_dir, target_size=(224, 224)):
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Iterate through each image in the directory
    for filename in os.listdir(image_dir):
        img_path = os.path.join(image_dir, filename)
        try:
            # Read the image
            img = cv2.imread(img_path)

            # Convert the image to RGB format
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # Resize the image
            img = cv2.resize(img, target_size)

            # Save the image as JPG format
            output_path = os.path.join(output_dir, os.path.splitext(filename)[0] + '.jpg')
            cv2.imwrite(output_path, cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

            print(f"Image '{img_path}' converted and resized successfully.")
        except Exception as e:
            print(f"Error processing image '{img_path}': {e}")

# Define input and output directories
image_dir = '/content/dataset/ukraine_war/ukraine_war'
output_dir = '/content/dataset/ukraine_war_resized'

# Convert and resize images
convert_and_resize_images(image_dir, output_dir)

import os
import cv2

def check_images(directory):
    image_formats = set()
    image_sizes = set()
    num_images = 0

    # Iterate through each file in the directory
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        # Check if the file is an image
        if os.path.isfile(filepath) and any(filename.lower().endswith(ext) for ext in ['.jpg', '.jpeg', '.png']):
            # Increment the count of images
            num_images += 1
            # Read the image using OpenCV
            image = cv2.imread(filepath)
            if image is not None:
                # Get the image format
                image_format = filename.split('.')[-1]
                image_formats.add(image_format)
                # Get the image size
                image_size = tuple(image.shape[1::-1])
                image_sizes.add(image_size)
            else:
                print(f"Error: Unable to read image '{filename}'")

    # Print the results
    print(f"Number of images: {num_images}")
    print(f"Image formats found: {image_formats}")
    print(f"Image sizes found: {image_sizes}")

# Define the directory containing the images
image_directory = '/content/dataset/ukraine_war_resized'

# Call the function to check images
check_images(image_directory)
# Out:
# Image '/content/dataset/ukraine_war/ukraine_war/4fh.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6j.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/437.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/96.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/438.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/39.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b55.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/559.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/332.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f22.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/541.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b7.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/776d.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/760.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f1.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c24.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4g.png.5' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/n2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/32da.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/t2.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5g.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/n77.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f43.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8173.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/556.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/799.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/v7.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g5d.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/78.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/44334.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/a4.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/58.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6665.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8115.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8404.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/fu2.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d35.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/74.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/445.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5570.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8398.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d6.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/355.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5gh.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/77h.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6662.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8160.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5gj.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/t9.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5g8.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/79.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/46.png.6' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/324.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/e12.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/752.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/l8.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b76.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/547.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/87.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/443.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/335s.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/57h.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f24.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/m88.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ff2v.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/cd.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/33e.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4790.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/43t.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/36h.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/21d.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4b.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7688.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/760.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/23.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/436.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/m1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/36.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8020.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/17.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/l8.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/580.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-9316.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/670.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/366.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/34.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8025.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/223.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/874.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8021.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/1d.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/688.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/790.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ut.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f565.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/v60.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4k.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f2.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/14.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8119.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5580.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g7.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/fhj.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4433.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/59.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3g.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/48.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b1.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/412.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8053.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/321.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/65.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g89.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/v56.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g00.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/gy6.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4800.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/77690.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/i3.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5gk.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4ff.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7u5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5580.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/v2.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/89.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-9429.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/l0.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/u8.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/75.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/774.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/78.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8646.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/buu.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4135.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8134.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/51.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/659.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/tr2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4r.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/m2.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/776.png.5' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/554.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/a1.png.5' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f6.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8285.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/h7.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5570.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/350.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/l5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/983.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f25.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8261.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4899.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3313.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/58.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7766.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/35.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3dh.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/98.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/m99.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/u1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/33177.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3317.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/u6.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7u5.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3316.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/k8.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f430.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/mp.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ds.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/t12.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g59.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/dg.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/542.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/p1.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/355.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g9.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/41.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/84.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5790.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/223.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r1.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f7.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/223.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g3.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/559.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/j2.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/355.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/u1.jpg.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/at1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3d1d.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/1366.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6652.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/j8.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g544.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5488.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/421.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d1.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/567.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/dgj.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4g.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8143.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/mn6.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/33f.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/489.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c2.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/380.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/n8.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/270.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f22.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/652.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/386.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/8879.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g544.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b6.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/46.png.7' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7763.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/764.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8407.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/u9.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/76j.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/114.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3v.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f57.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/546.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b0.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/346.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f114.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4fj.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/jj.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/368.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4y.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/488.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3r5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c1.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r1.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4g2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4t.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6hk.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/329.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3d.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/42.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4488.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/297.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/328.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3dd1.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/q1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/480.png.6' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/554f.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f24.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f30.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d17.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/433.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/o9.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/46800.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/765.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/52.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5gh.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d240.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/85.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/480.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8472.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/443.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-9011.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/64.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6522.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5799.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/aa4.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ff4.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/p1.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/54220.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/412.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/689.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/543.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/e1.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/776.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/480.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r2.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/341.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/344.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f13.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4437.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5547.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/tt2.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4h.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/37.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/55488.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/a3.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/668.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/629.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/431d.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/763.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f2b.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/rgg.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/332.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/43100.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ds.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/468.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/h79.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/1245.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b4.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/41.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/n86.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/449.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/652.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8289.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4433.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ca1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/jo.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g76.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/bl.png.5' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/o9.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/665333.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/699.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g43.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/u1.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3d1.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4dh.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ds6.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ty.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/544.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/44366.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/n89.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4703.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/bb1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r44.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b90.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/678.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8472.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/44fss.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3k.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/557.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8019.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/h54.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/346.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/361.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5g2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r21.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/44.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g5.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g3.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f431.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8156.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4g.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/k9.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8276.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5gg.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f234.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/43119.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5t.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/15.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8449.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/55444.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f2h.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/445.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c5.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f33.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/46805.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5f2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/2240.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-9035.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/42.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ka1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4373.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3f.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3tyu.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/33190.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ff4.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/479p.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g8.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/n8.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/312.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/l3.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/447.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/29.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f3.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3244.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3d1.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4h.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d23.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/v90.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5577.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/578.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/665f.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/474.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/51.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r2.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/n2.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8275.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8445.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g32.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f69.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d1d.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8948.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b1.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/324.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/245.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/358.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d2.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4fh.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/653.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/l7.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/x1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/j4.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ddfg.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/x2.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g3.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/2o9.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ttrr.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/63.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d3.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3e.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d335.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d14g.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4435.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/v44.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/663.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/435.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/gg5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4433.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/764.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/q8.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f3hj.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5g.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/698.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/43111.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/33290.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5g.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/1d4.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ff4k.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/cf2.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g7.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/54g.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/659.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d3.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5422.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/m4.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/542f.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/l9.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7760.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b8.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/800.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b00.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d332.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3351.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/470.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7900.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8345.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/l2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/j8.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f69.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r6.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/gg6.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/h5.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/bb665.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4311.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3d3.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f70.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8471.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/413.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4317.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/e11.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/581.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8472.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/k9.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/79.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5490.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d67.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ff1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/60.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/43.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/32.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/65.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5j.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8260.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/h7.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4689.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/tt1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7764.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/42.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b788.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/46.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/88kj.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/t1.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/467.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3d5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/43y.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d1k.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/gm.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/112.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/776.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/447.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3h.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4321.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/446.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6h.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g3.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f15.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/770.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5gg.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/a1.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c2.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/653.png' converted and resized successfully.
# ...
# Image '/content/dataset/ukraine_war/ukraine_war/c0.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/90.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c2.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8249.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8272.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c13.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f7.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d43.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/t1.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f3.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3h.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5424.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/479.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/fs.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d31.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/67.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/vv31.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/310.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/t4.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/545.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/41.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/32ff.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/m2.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/t5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4w.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/346.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r133.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6658.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/221.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/318.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3ds1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/k2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/43.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/hhj.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/t3.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4315.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/125.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/46.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8643.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/55433.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b6.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4gd.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ug4.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3d.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/441.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/325.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/367.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3579.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/579.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6599.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/47h.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/ug1.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5808.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/795.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7644.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/dg.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/777.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/31.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/hh3.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/335.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r3.jpg.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8037.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d136.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/357.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f43.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6656.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f56.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/489.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/442.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c2.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/dbb.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/435.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4310.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/79p.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/411.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-9133.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/872.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/545.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/7i.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b77.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3380.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b2.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f4.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/24.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/234.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8017.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4318.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/u60.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/44fj.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b788.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/877.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r3.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/359.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5y.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/tt6.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/872.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/b7.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4366.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8077.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d331.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/976.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8232.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/579.png.4' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/d1.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/40.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4456.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/y6.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8284.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f86.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4413.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4433.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/dd1.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4fh.png.5' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/321.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/43111.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/u8.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4fs.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/9p.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/443o.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/vb.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/68.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/j77.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/n1.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/54.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/542.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/443.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g6.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/553.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/331.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8396.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6h7.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4178.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/321.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/489.png.3' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/utt.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/799.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/985.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5gk.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4f.png.2' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5990.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/bj.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/480.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/r35.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/43gdp.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/544.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/2hs.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/443l.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/570.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/Screenshot-8400.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5426.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/j7.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g43g.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/4566.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/f57.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/6hf.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5583.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/369.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/p5.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3k.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/5578.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/3322.png' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/c7.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/72.png.1' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/cf1.jpg' converted and resized successfully.
# Image '/content/dataset/ukraine_war/ukraine_war/g59.png.1' converted and resized successfully.
# Number of images: 1683
# Image formats found: {'jpg'}
# Image sizes found: {(224, 224)}

# %% [markdown]
# #### Compare if original and encoded images are lossy or lossless

# %%
import os
from PIL import Image
import numpy as np

def message_to_bin(message):
    binary = ''.join(format(ord(i), '08b') for i in message)
    return binary

def modify_pixel(pixel, binary_message, index):
    if index < len(binary_message):
        pixel = (pixel & ~1) | int(binary_message[index])
    return pixel

def encode_image(img_path, message):
    img = Image.open(img_path)
    binary_message = message_to_bin(message) + '11111111'  # Delimiter to indicate end of message
    pixels = np.array(img)

    index = 0
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            for k in range(3):  # Iterate over RGB channels
                if index < len(binary_message):
                    pixels[i, j, k] = modify_pixel(pixels[i, j, k], binary_message, index)
                    index += 1

    encoded_img = Image.fromarray(pixels)
    return encoded_img

def compare_file_sizes(original_img_path, encoded_img_path):
    original_size = os.path.getsize(original_img_path)
    encoded_size = os.path.getsize(encoded_img_path)
    print("Original image size:", original_size, "bytes")
    print("Encoded image size:", encoded_size, "bytes")
    if original_size == encoded_size:
        print("The encoded image size is the same as the original image size. It suggests lossless encoding.")
    else:
        print("The encoded image size is different from the original image size. It suggests lossy encoding.")

# Usage
original_img_path = "/content/dataset/ukraine_war/ukraine_war/07.png"
encoded_img_path = "/content/07encoded_image.jpg"
message = "Your secret message here"

# Encoding the image
encoded_img = encode_image(original_img_path, message)
encoded_img.save(encoded_img_path)

# Compare file sizes
compare_file_sizes(original_img_path, encoded_img_path)

def compare_images(img_path1, img_path2):
    img1 = Image.open(img_path1)
    img2 = Image.open(img_path2)

    pixels1 = np.array(img1)
    pixels2 = np.array(img2)

    if np.array_equal(pixels1, pixels2):
        print("The pixel values of the original and encoded images are exactly the same. Lossless encoding.")
    else:
        print("The pixel values of the original and encoded images are different. Lossy encoding.")

# Usage
original_img_path = "/content/dataset/ukraine_war/ukraine_war/07.png"
encoded_img_path = "/content/07encoded_image.jpg"

# Compare pixel values
compare_images(original_img_path, encoded_img_path)
# Out:
# Original image size: 1182471 bytes
# Encoded image size: 128945 bytes
# The encoded image size is different from the original image size. It suggests lossy encoding.
# The pixel values of the original and encoded images are different. Lossy encoding.

# %%
from PIL import Image
import numpy as np

def add_noise(img, mean=0, var=0.01):
    """ Add Gaussian noise to an image. """
    row, col, ch = img.shape
    sigma = var**0.5
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    gauss = gauss.reshape(row, col, ch)
    noisy = img + gauss
    return np.clip(noisy, 0, 255).astype(np.uint8)

def crop_image(img, start_x, start_y, end_x, end_y):
    """ Crop an image. """
    return img[start_y:end_y, start_x:end_x]

def rotate_image(img, angle):
    """ Rotate an image. """
    return img.rotate(angle, expand=True)

def tamper_image_path(img_path, save_path='tampered_image.png'):
    img = Image.open(img_path)
    img = np.array(img)

    # Optionally add noise
    img = add_noise(img)

    # Optionally crop the image (specify the crop area)
    #img = crop_image(img, 50, 50, 200, 200)  # Adjust these values based on your image dimensions

    # Convert back to PIL Image to rotate
    img = Image.fromarray(img)
    #img = rotate_image(img, 45)  # Rotate by 45 degrees

    return img

def tamper_images_data(image_dir, output_dir, target_size=(224, 224)):
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    count = 0
    # Iterate through each image in the directory
    for filename in os.listdir(image_dir):
        if count==1400:
          break
        img_path = os.path.join(image_dir, filename)
        try:

            img = tamper_image_path(img_path)

            # Save the image as JPG format
            output_path = os.path.join(output_dir, os.path.splitext(filename)[0] + '_tampered.jpg')
            img.save(output_path)

            print(f"Image '{img_path}' tampered successfully.")
            count+=1
        except Exception as e:
            print(f"Error processing image '{img_path}': {e}")

# Define input and output directories
image_dir = '/content/dataset/ukraine_war_resized'
output_dir = '/content/dataset/ukraine_war_tampered'

tamper_images_data(image_dir,output_dir)
# Out:
# Image '/content/dataset/ukraine_war_resized/4313.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6j.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b55.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/559.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/332.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4466.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f68.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/13.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5548.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b7.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/n5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/570.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/57j.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/58p.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5gl.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/556.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/27.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/311.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/799.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/663.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/44334.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/a4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6665.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/df.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/fu2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/417.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j2.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4311.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4f28.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6662.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/341.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f44.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f45.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5g8.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/135.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/a1.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8214.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/dg.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/o9.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3d5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d136.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8075.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4366.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4131.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ff2v.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/cd.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/469.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3k.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/326.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/542g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/46h.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g89.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f57.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8146.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/138.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/659.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g5d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/l6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g66.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f16.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/s3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/325.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b10.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-9319.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/33290.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8400.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/346.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3380.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/1d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/654.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3dh.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ut.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f433.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8113.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4f2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5j.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/525.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5g2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/o98.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4y.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3v.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/431g.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43f1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/47.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f69.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/a3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/316.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j77.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/42.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/u1.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5588.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/77690.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g544.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/i3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/359.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3244.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8144.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4431.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b67.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8952.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/v56.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/329.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ff4467.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6680.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ds6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/178.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8114.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/buu.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5490.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/32fd.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4899.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/31g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/318.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-9133.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f15.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/l8.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/680.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5800.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/698.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7766.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/98.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/m99.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/872.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/dd3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/33160.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/as43.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/765.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/u6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/567.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7u5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/680o.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f430.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/mp.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/t12.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/33180.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/n77.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g789.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j1.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/dg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/449.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4y8.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/86.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/p1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3dg0.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7k.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/84.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/c4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5790.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/331.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f79.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/223.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8111.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-9428.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/37.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/55488.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4566.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8124.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/554.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6652.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j8.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6800.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/670.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/y8.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ff7.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5gj.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/468.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g544.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/fhj.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5577.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h77.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/60.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/8879.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5h.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/v98.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r44.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/446.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/n8.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8249.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b900.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/415.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43133.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f21.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4f220.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/324.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b0.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f4d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/jj.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r33.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7763.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/456.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/c1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6hk.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3359.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6656.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3dd1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4689.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8149.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/413.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/59.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8215.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4dh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/64.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6522.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d240.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f233.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/aa4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/135.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/54220.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4fj.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5580.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43134.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43g.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f1.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/n1.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/e1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8931.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d69.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/468p.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/tt2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/358.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/v8.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/l2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-9036.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f4.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/347.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/471.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/753.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-9035.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3dh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h79.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8218.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5433.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/553.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3167.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/32.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4318.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/y6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/55448.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5gk.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/98u.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/331.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/15.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-9429.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/a2.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f67.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/678.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ug1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g8k.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/2hs.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/589.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8161.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/sa.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8143.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/448.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6688.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/543.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/44.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/07.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4f1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8219.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/653.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8305.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/55444.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/425.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/c5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4g2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/l9.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8192.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/558.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d6.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43f.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/33f.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8472.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ff4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ff13.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3256.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8073.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/p2.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3351.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8138.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3217.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4331.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8285.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4gf.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4432.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/35g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/665f.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/51.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/779.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g32.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/310.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d1d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4413.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/115.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ddfg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/578.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/x2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5y5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3r5.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/2o9.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ttrr.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/c24.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d1g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4435.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4470.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/557.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d1h.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4fgh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f46.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/360.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43100.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/1d4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/cf2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g7.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f2hp.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5422.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f9.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/87.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/557.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b00.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5247.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3fr.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/p5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7900.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/gg6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/443689.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/m2.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/776d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4w.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8026.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3368.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f246.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4f13.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/350.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/653.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/328.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8211.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/443.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d2g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/447.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/p1.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5554.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/465.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/431.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/8k.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/581.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3v.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/p2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/52.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/n2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3d1d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/t1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/68.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43y.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d13.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/mn6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/47.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/gm.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/78.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/33213.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/44565.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/42d.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/19.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3t.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/a5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/1g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/dfg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8447.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4f7.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/665h.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/v0.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r134.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/413.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/549.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3313.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/297.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/v90.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h7.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/665.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/y1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5gh.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/bnm.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3212.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/763.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/542f.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6880.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j8l.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/542.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/790.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8116.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/437.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/fu1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/321.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3315.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4369.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d67.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4432.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j7.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/467.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d17.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/e11.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/524.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/479p.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/24.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/318.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/49.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/gy6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4h.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/699.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/554f.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/680.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/at3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/344.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/33113.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4689.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8103.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/31d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/33177.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g5.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/v9.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f565.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/435.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/686.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d14g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/fu13.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6h7.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3321.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/795.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r35.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/gg2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/dd12.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8069.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8160.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/c2.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/335.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/q9.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f24.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8367.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/16.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ta2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5542.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/85.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/433.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/412.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/q5.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/57h.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3322.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4fhh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ta1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/164.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/79.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f25.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r2.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/66.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/u4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/334.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/658.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/o1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/38.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5577.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/54.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g9.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/q4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/a1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/47h.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8054.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5488.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/br1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6659.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f48.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/uk.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7u.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/fs.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5gh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6599.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/tr2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/460.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/688.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f8.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3588.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/n89.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5583.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/t5.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f24.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3d20.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8074.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/k2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f22.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f7.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/652.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g68.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/hd.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/u2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/130.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7755.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/tr1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8217.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5548.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/vv31.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/u1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/m2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f43.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43177.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6h.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/437.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/689.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d12.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/547.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/412.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/235.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/112.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/36p.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/bb3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4fs.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/652.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/367.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/445.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4j.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3d1.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8389.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/nm8.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g9.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/776.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3d29.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/vb.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d23.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ca2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r4.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/431.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/8u.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/q1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/k1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/431v.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8115.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/as44.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f35.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/57880.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3k.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8450.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/a2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/122.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/24f.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/159.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/449.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4156.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5540.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/467.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/m88.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/a11.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g433.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8366.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h7.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8224.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/114.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4h.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/468.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/2fl.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/i2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4370.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/542.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/442.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/m7.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/tt1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j4.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5411.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d331.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8156.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h7.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/71.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/k8.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b788.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/63.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/t1.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4fj.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/v7.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/37.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6996.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7699.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/448.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/67.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/421.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/36.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/554.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4fh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/542j.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/14.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h54.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b6.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/8873.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h78.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/469.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/2r.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/516.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3317.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/790.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/15.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/629.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/317.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/77633.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/553.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b1.png.jpg' tampered successfully.
# ...
# Image '/content/dataset/ukraine_war_resized/gh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f3.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6y.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8260.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f60.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8471.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g0.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f65.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/74.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/331d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/36h.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/bb665.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/v6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8261.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5557.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5541.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/dj.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5426.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/76m.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-9320.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8646.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/79.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d15.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/330.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8486.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g42.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d12.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/887.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/324.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/37h.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/43fhj.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g1.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/66556.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8210.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/356.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4f.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8216.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h9.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/42g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/557723.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8143.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8119.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4456.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5gg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/33.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4890.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4436.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g43g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/40.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8457.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/28.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/c8.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6888.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7762.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/73.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4gd.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g59.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6hh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/l3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f48.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/361.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4315.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-9318.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/86.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5gj.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/rg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8399.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j76.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/774.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/439.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/dd2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/987.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ug3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/hh3.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/44f1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/317.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/46805.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/69.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f56.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/13.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3318.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/46k.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3ds.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/67.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/653g.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f87.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/461.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4315.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4322.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/32d.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ttr.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/sfg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4799.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4ff.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ff1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8209.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ukk.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/c5.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/319.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8016.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4178.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/12.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g8.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8396.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h0.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b76.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/976.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6655.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/n6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/fu12.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/479.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3rr.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/65.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8112.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/7ip.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/1dg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/s2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/nm.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4133.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/h0.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/2gh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6hj.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4438.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r45.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/m6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/345.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/34.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/t2.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8561.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4135.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d33.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/450.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5808.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4fh.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/113.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g5mm.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ff22.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g55.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4ffh.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8070.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/470.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/16.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d46.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/360.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/97.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f69.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f57.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3h.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/6658.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/t2.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/c7.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/v77.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8019.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4311.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/32.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8169.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/24.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/900.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/r21.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/416.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4477.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/c1.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4488.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/n1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/76.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/42.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/at1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5570.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ff24.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ml.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/o9.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/ty.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8120.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5g7.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/886.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/499.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4680.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5422.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/433.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/f3hj.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/36hp.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/4f11.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/g1.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8345.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/5554.png.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8037.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8648.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/332.jpg.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/470.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3268.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-9134.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/b89.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/44133.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/n0.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j6.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/3da.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/Screenshot-8343.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/j767.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/d9.jpg' tampered successfully.
# Image '/content/dataset/ukraine_war_resized/86.png.jpg' tampered successfully.

# %%
image_directory = '/content/dataset/ukraine_war_tampered'

# Call the function to check images
check_images(image_directory)
compare_file_sizes('/content/dataset/ukraine_war_resized/07.jpg', '/content/dataset/ukraine_war_tampered/07_tampered.jpg')
compare_images('/content/dataset/ukraine_war_resized/07.jpg', '/content/dataset/ukraine_war_tampered/07_tampered.jpg')
# Out:
# Number of images: 1400
# Image formats found: {'jpg'}
# Image sizes found: {(224, 224)}
# Original image size: 35534 bytes
# Encoded image size: 16792 bytes
# The encoded image size is different from the original image size. It suggests lossy encoding.
# The pixel values of the original and encoded images are different. Lossy encoding.

# %%
import os
import shutil

image_dir = '/content/dataset/ukraine_war_resized'
image_dir2 = '/content/dataset/ukraine_war_tampered'
image_final_dir = '/content/dataset/ukraine_war_finaldata'

# Create the final directory if it doesn't exist
if not os.path.exists(image_final_dir):
    os.makedirs(image_final_dir)

# Copy images from image_dir to image_final_dir
for filename in os.listdir(image_dir):
    shutil.copy(os.path.join(image_dir, filename), image_final_dir)

# Copy images from image_dir2 to image_final_dir
for filename in os.listdir(image_dir2):
    shutil.copy(os.path.join(image_dir2, filename), image_final_dir)

print("Images copied successfully to", image_final_dir)
check_images(image_final_dir)
# Out:
# Images copied successfully to /content/dataset/ukraine_war_finaldata
# Number of images: 3083
# Image formats found: {'jpg'}
# Image sizes found: {(224, 224)}

# %%
def copy_to_drive(colab_folder_path, drive_folder_path):
   colab_folder_path = '/content/dataset/ukraine_war_finaldata'
   drive_folder_path = '/content/drive/MyDrive/Courses/Sem 2/DL/ukraine_war_finaldata'

  # Copy the folder from Colab to Drive
  shutil.copytree(colab_folder_path, drive_folder_path)

  print("Folder copied successfully to Google Drive.")

# %%
import os
import random
import shutil

# Define source directories
image_dir = '/content/dataset/ukraine_war_resized'
tampered_dir = '/content/dataset/ukraine_war_tampered'

# Define destination directory
destination_dir = '/content/dataset/final'

# Function to copy a subset of images from source directory to destination directory
def copy_subset_images(source_dir, dest_dir, num_images):
    # Get a list of all files in the source directory
    files = os.listdir(source_dir)
    # Shuffle the list
    random.shuffle(files)
    # Take a subset of the shuffled list
    subset = files[:num_images]
    # Copy each file from the subset to the destination directory
    for filename in subset:
        shutil.copy(os.path.join(source_dir, filename), dest_dir)

# Copy subset of original images
copy_subset_images(image_dir, destination_dir, 200)

# Copy subset of tampered images
copy_subset_images(tampered_dir, destination_dir, 200)

print("Subset of 200 original and 200 tampered images copied successfully to", destination_dir)
# Out:
# Subset of 200 original and 200 tampered images copied successfully to /content/dataset/final

# %%
import os

# Define the directory
destination_dir = '/content/dataset/final'

# Get the list of files in the directory
files = os.listdir(destination_dir)

# Count the number of files with "tampered" in their name
tampered_count = sum('tampered' in filename for filename in files)

print("Number of files with 'tampered' in their name:", tampered_count)
# Out:
# Number of files with 'tampered' in their name: 200

# %% [markdown]
# ###Inception_v3

# %% [markdown]
# #### Non encoded images vs Tampered Images

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.jpg')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations for Inception v3
transform = transforms.Compose([
    transforms.Resize(299),  # Resize so the smallest side is 299 pixels
    transforms.CenterCrop(299),  # Crop to 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/dataset/final', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained Inception v3 model and modify it for binary classification
model = models.inception_v3(pretrained=True)
# Handle the auxiliary net
aux_in_features = model.AuxLogits.fc.in_features
model.AuxLogits.fc = nn.Linear(aux_in_features, 2)
# Handle the primary net
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs, aux_outputs = model(inputs)  # Inception model outputs main and auxiliary outputs
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        loss = loss1 + 0.4 * loss2  # Combine losses
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)  # Ignore auxiliary outputs during evaluation
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1, Loss: 0.6973464488983154
# Epoch 2, Loss: 0.7377987504005432
# Epoch 3, Loss: 0.6356834769248962
# Epoch 4, Loss: 0.3975643217563629
# Epoch 5, Loss: 0.11516178399324417
# Epoch 6, Loss: 0.48788732290267944
# Epoch 7, Loss: 0.061480358242988586
# Epoch 8, Loss: 0.6364486813545227
# Epoch 9, Loss: 0.08867169916629791
# Epoch 10, Loss: 1.2352858781814575
# Accuracy: 91.25%

# %% [markdown]
# #### Encoded images with Tampering

# %%
img_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50'
# if not os.path.exists(img_dir):
#     os.makedirs(img_dir)
# copy_subset_images('/content/dataset/ukraine_war_resized', img_dir, 50)

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import os

#Load pre-trained ResNet50 model
model = ResNet50(weights='imagenet')

def encode_image(img,message):
  def message_to_bin(message):
      binary = ''.join(format(ord(i), '08b') for i in message)
      return binary

  def modify_pixel(pixel, binary_message, index):
      if index < len(binary_message):
          pixel = (pixel & ~1) | int(binary_message[index])
      return pixel

  def enc_image(img, message):
      binary_message = message_to_bin(message) + '11111111'  # Delimiter to indicate end of message
      pixels = np.array(img)

      index = 0
      for i in range(pixels.shape[0]):
          for j in range(pixels.shape[1]):
              for k in range(3):  # Iterate over RGB channels
                  if index < len(binary_message):
                      pixels[i, j, k] = modify_pixel(pixels[i, j, k], binary_message, index)
                      index += 1

      encoded_img = Image.fromarray(pixels)
      return encoded_img
  return enc_image(img,message)


def decode_image(img):

    pixels = np.array(img)
    binary_message = ''
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            for k in range(3):
                binary_message += str(pixels[i, j, k] & 1)
                if binary_message[-8:] == '11111111':  # Check for delimiter
                    return ''.join(chr(int(binary_message[i:i+8], 2)) for i in range(0, len(binary_message)-8, 8))
    return None

# # Define the path to your dataset
dataset_path = img_dir

# Iterate through each image in the dataset
for filename in os.listdir(dataset_path):
    img_path = os.path.join(dataset_path, filename)
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    # Perform inference
    preds = model.predict(x)
    # Decode and print the top-3 predicted classes
    map = decode_predictions(preds, top=3)[0]
    print(f'Predicted for {filename}:', map[0][1])
    secret = f'TOPSECRET: This is the {map[0][1]}.'
    encoded_img = encode_image(img, secret)
    encoded_img.save(img_path.replace('jpg','png'))
    #print("Decoded: ", decode_image(encoded_img))
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted for c4.jpg: snowplow
# 1/1 [==============================] - 0s 355ms/step
# Predicted for 3234.jpg: tow_truck
# 1/1 [==============================] - 0s 382ms/step
# Predicted for v90.jpg: half_track
# 1/1 [==============================] - 0s 359ms/step
# Predicted for dg.jpg: tank
# 1/1 [==============================] - 0s 337ms/step
# Predicted for br2.jpg: tank
# 1/1 [==============================] - 0s 370ms/step
# Predicted for 3322.jpg: cliff
# 1/1 [==============================] - 0s 338ms/step
# Predicted for vb.jpg: shower_curtain
# 1/1 [==============================] - 0s 335ms/step
# Predicted for 43fhl.jpg: half_track
# 1/1 [==============================] - 0s 372ms/step
# Predicted for 6688.jpg: tank
# 1/1 [==============================] - 0s 332ms/step
# Predicted for q3.jpg: trailer_truck
# 1/1 [==============================] - 0s 214ms/step
# Predicted for 6888.jpg: stove
# 1/1 [==============================] - 0s 203ms/step
# Predicted for Screenshot-9133.jpg: window_screen
# 1/1 [==============================] - 0s 201ms/step
# Predicted for tt1.jpg: park_bench
# 1/1 [==============================] - 0s 202ms/step
# Predicted for Screenshot-8471.jpg: passenger_car
# 1/1 [==============================] - 0s 208ms/step
# Predicted for t11.jpg: oscilloscope
# 1/1 [==============================] - 0s 215ms/step
# Predicted for 85.jpg: half_track
# 1/1 [==============================] - 0s 203ms/step
# Predicted for u4.jpg: lakeside
# 1/1 [==============================] - 0s 197ms/step
# Predicted for l2.jpg: tank
# 1/1 [==============================] - 0s 204ms/step
# Predicted for d130.jpg: tank
# 1/1 [==============================] - 0s 204ms/step
# Predicted for 553.png.jpg: web_site
# 1/1 [==============================] - 0s 221ms/step
# Predicted for 460.jpg: ashcan
# 1/1 [==============================] - 0s 206ms/step
# Predicted for 44565.jpg: half_track
# 1/1 [==============================] - 0s 212ms/step
# Predicted for g32.jpg: half_track
# 1/1 [==============================] - 0s 264ms/step
# Predicted for 42.jpg: crane
# 1/1 [==============================] - 0s 351ms/step
# Predicted for e12.jpg: tank
# 1/1 [==============================] - 0s 341ms/step
# Predicted for 4790.jpg: tank
# 1/1 [==============================] - 0s 335ms/step
# Predicted for 3k.jpg: monitor
# 1/1 [==============================] - 0s 377ms/step
# Predicted for k89.jpg: worm_fence
# 1/1 [==============================] - 0s 381ms/step
# Predicted for l6.jpg: aircraft_carrier
# 1/1 [==============================] - 0s 364ms/step
# Predicted for a2.png.jpg: web_site
# 1/1 [==============================] - 0s 359ms/step
# Predicted for Screenshot-8450.jpg: switch
# 1/1 [==============================] - 0s 387ms/step
# Predicted for 55448.jpg: web_site
# 1/1 [==============================] - 0s 249ms/step
# Predicted for b67.jpg: tank
# 1/1 [==============================] - 0s 208ms/step
# Predicted for 312.jpg: tank
# 1/1 [==============================] - 0s 226ms/step
# Predicted for 7760.jpg: web_site
# 1/1 [==============================] - 0s 208ms/step
# Predicted for 763.jpg: web_site
# 1/1 [==============================] - 0s 226ms/step
# Predicted for 5g8.jpg: lakeside
# 1/1 [==============================] - 0s 207ms/step
# Predicted for 5490.jpg: submarine
# 1/1 [==============================] - 0s 206ms/step
# Predicted for 332.jpg.jpg: valley
# 1/1 [==============================] - 0s 208ms/step
# Predicted for Screenshot-8486.jpg: trailer_truck
# 1/1 [==============================] - 0s 203ms/step
# Predicted for 4fs.png.jpg: lumbermill
# 1/1 [==============================] - 0s 202ms/step
# Predicted for g7889.jpg: tow_truck
# 1/1 [==============================] - 0s 212ms/step
# Predicted for n0.jpg: steam_locomotive
# 1/1 [==============================] - 0s 225ms/step
# Predicted for 33177.jpg: jeep
# 1/1 [==============================] - 0s 220ms/step
# Predicted for h65.png.jpg: castle
# 1/1 [==============================] - 0s 203ms/step
# Predicted for d12.png.jpg: geyser
# 1/1 [==============================] - 0s 217ms/step
# Predicted for 412.png.jpg: lumbermill
# 1/1 [==============================] - 0s 226ms/step
# Predicted for 443fp.jpg: geyser
# 1/1 [==============================] - 0s 203ms/step
# Predicted for 4456.png.jpg: jeep
# 1/1 [==============================] - 0s 217ms/step
# Predicted for 5247.jpg: sundial

# %%
from PIL import Image
import numpy as np

def decode_image(img):

    pixels = np.array(img)
    binary_message = ''
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            for k in range(3):
                binary_message += str(pixels[i, j, k] & 1)
                if binary_message[-8:] == '11111111':  # Check for delimiter
                    return ''.join(chr(int(binary_message[i:i+8], 2)) for i in range(0, len(binary_message)-8, 8))
    return None

def tamper_image(img, save_path='tampered_image.png'):
    img = np.array(img)

    # Optionally add noise
    img = add_noise(img)

    # Optionally crop the image (specify the crop area)
    #img = crop_image(img, 50, 50, 200, 200)  # Adjust these values based on your image dimensions

    # Convert back to PIL Image to rotate
    img = Image.fromarray(img)
    #img = rotate_image(img, 45)  # Rotate by 45 degrees
    return img


#encoded_image = encode_image('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50/312.png', 'YourSecretCode123')
tamper_image = tamper_image(Image.open('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50/312.png'))

decoded_message = decode_image(tamper_image)
print(decoded_message)
# Out:
# ìMË¿g	öFÙZcê¶Þ±¶w·ÀrÜÃHk6MÐPbc´ÎÀ÷_¡ýd©ÃieÌV¾Ã·gÎ9U6@.=È!j¿

# %% [markdown]
# #### Tamper Encoded Data - Encoded_50

# %%
def tamper_images_data(image_dir, output_dir, target_size=(224, 224)):
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    count = 0
    # Iterate through each image in the directory
    for filename in os.listdir(image_dir):
        if count==1400:
          break
        img_path = os.path.join(image_dir, filename)
        try:

            img = tamper_image_path(img_path)

            # Save the image as JPG format
            output_path = os.path.join(output_dir, os.path.splitext(filename)[0] + '_tampered.png')
            img.save(output_path)

            print(f"Image '{img_path}' tampered successfully.")
            count+=1
        except Exception as e:
            print(f"Error processing image '{img_path}': {e}")

def tamper_image_path(img_path, save_path='tampered_image.png'):
    img = Image.open(img_path)
    img = np.array(img)

    # Optionally add noise
    img = add_noise(img)

    # Optionally crop the image (specify the crop area)
    #img = crop_image(img, 50, 50, 200, 200)  # Adjust these values based on your image dimensions

    # Convert back to PIL Image to rotate
    img = Image.fromarray(img)
    #img = rotate_image(img, 45)  # Rotate by 45 degrees

    return img
tamper_images_data('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50', '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50')

# %% [markdown]
# #### ResNet

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained model and modify it for binary classification
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# Epoch 1, Loss: 0.8656717538833618
# Epoch 2, Loss: 0.7513283491134644
# Epoch 3, Loss: 0.854275643825531
# Epoch 4, Loss: 0.9165647029876709
# Epoch 5, Loss: 0.6640243530273438
# Epoch 6, Loss: 0.7973805665969849
# Epoch 7, Loss: 0.7519326210021973
# Epoch 8, Loss: 0.7097175717353821
# Epoch 9, Loss: 1.1205084323883057
# Epoch 10, Loss: 0.5354132652282715
# Accuracy: 54.0%

# %% [markdown]
# ####Inception_v3

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations for Inception v3
transform = transforms.Compose([
    transforms.Resize(299),  # Resize so the smallest side is 299 pixels
    transforms.CenterCrop(299),  # Crop to 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained Inception v3 model and modify it for binary classification
model = models.inception_v3(pretrained=True)
# Handle the auxiliary net
aux_in_features = model.AuxLogits.fc.in_features
model.AuxLogits.fc = nn.Linear(aux_in_features, 2)
# Handle the primary net
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs, aux_outputs = model(inputs)  # Inception model outputs main and auxiliary outputs
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        loss = loss1 + 0.4 * loss2  # Combine losses
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)  # Ignore auxiliary outputs during evaluation
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1, Loss: 1.3888630867004395
# Epoch 2, Loss: 1.0894582271575928
# Epoch 3, Loss: 1.636603832244873
# Epoch 4, Loss: 1.6251716613769531
# Epoch 5, Loss: 1.0721657276153564
# Epoch 6, Loss: 1.2732505798339844
# Epoch 7, Loss: 1.1816078424453735
# Epoch 8, Loss: 1.679003357887268
# Epoch 9, Loss: 0.6254927515983582
# Epoch 10, Loss: 1.2098230123519897
# Accuracy: 48.0%

# %% [markdown]
# #### Vgg16

# %%
# Load the dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained VGG16 model and modify it for binary classification
model = models.vgg16(pretrained=True)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 2)  # Modify the classifier layer

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1, Loss: 0.6140020489692688
# Epoch 2, Loss: 0.720977783203125
# Epoch 3, Loss: 0.8592000603675842
# Epoch 4, Loss: 0.7762177586555481
# Epoch 5, Loss: 0.6702403426170349
# Epoch 6, Loss: 0.7327219247817993
# Epoch 7, Loss: 0.6631041765213013
# Epoch 8, Loss: 0.6718435883522034
# Epoch 9, Loss: 0.7308367490768433
# Epoch 10, Loss: 0.7235779166221619
# Accuracy: 47.0%

# %% [markdown]
# #### Encoded and compressed images with Tampering

# %% [markdown]
# #### Lossy and Lossless compression- Encoded_50_compressed Lossy/Lossless

# %%
import os
from PIL import Image

# Define source directory
source_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50'

# Define destination directories for lossy and lossless compression
destination_lossy = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossy'
destination_lossless = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossless'

# Create destination directories if they don't exist
os.makedirs(destination_lossy, exist_ok=True)
os.makedirs(destination_lossless, exist_ok=True)

# Iterate over files in the source directory
for filename in os.listdir(source_dir):
    # Check if the filename does not contain 'tampered'
    if 'tampered' not in filename:
        # Construct the full path of the source file
        source_file = os.path.join(source_dir, filename)

        # Open the image
        img = Image.open(source_file)

        # Save the image with lossy compression
        img.save(os.path.join(destination_lossy, filename), quality=80)  # Adjust quality as needed

        # Save the image with lossless compression
        img.save(os.path.join(destination_lossless, filename), format='PNG')

print("Images moved and compressed successfully.")
# Out:
# Images moved and compressed successfully.

# %% [markdown]
# #### Tamper Encoded+Compressed Data

# %%
def add_noise(img, mean=0, var=0.01):
    """ Add Gaussian noise to an image. """
    row, col, ch = img.shape
    sigma = var**0.5
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    gauss = gauss.reshape(row, col, ch)
    noisy = img + gauss
    return np.clip(noisy, 0, 255).astype(np.uint8)
tamper_images_data('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossy', '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossy')

tamper_images_data('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossless', '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossless')

# %% [markdown]
# #### ResNet for Lossy vs Lossless compression

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the Lossy dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossy', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained model and modify it for binary classification
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossy compression: {100 * correct / total}%')


# Load the Lossless dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossless', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained model and modify it for binary classification
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossless compression: {100 * correct / total}%')
# Out:
# Epoch 1, Loss: 0.6748802661895752
# Epoch 2, Loss: 1.2062875032424927
# Epoch 3, Loss: 0.8119528293609619
# Epoch 4, Loss: 0.6255300045013428
# Epoch 5, Loss: 1.1000237464904785
# Epoch 6, Loss: 0.867458701133728
# Epoch 7, Loss: 0.9236495494842529
# Epoch 8, Loss: 1.476010799407959
# Epoch 9, Loss: 0.8994950652122498
# Epoch 10, Loss: 1.5172618627548218
# Accuracy for Lossy compression: 50.0%
# Epoch 1, Loss: 1.0058207511901855
# Epoch 2, Loss: 0.7604208588600159
# Epoch 3, Loss: 1.203510046005249
# Epoch 4, Loss: 1.2051016092300415
# Epoch 5, Loss: 0.5238816142082214
# Epoch 6, Loss: 0.9600765705108643
# Epoch 7, Loss: 0.8668262362480164
# Epoch 8, Loss: 0.7841525673866272
# Epoch 9, Loss: 0.7749594449996948
# Epoch 10, Loss: 0.5793909430503845
# Accuracy for Lossless compression: 50.0%

# %% [markdown]
# ####Inception_v3 for Lossy vs Lossless comparison

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations for Inception v3
transform = transforms.Compose([
    transforms.Resize(299),  # Resize so the smallest side is 299 pixels
    transforms.CenterCrop(299),  # Crop to 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the Lossy dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossy', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained Inception v3 model and modify it for binary classification
model = models.inception_v3(pretrained=True)
# Handle the auxiliary net
aux_in_features = model.AuxLogits.fc.in_features
model.AuxLogits.fc = nn.Linear(aux_in_features, 2)
# Handle the primary net
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs, aux_outputs = model(inputs)  # Inception model outputs main and auxiliary outputs
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        loss = loss1 + 0.4 * loss2  # Combine losses
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)  # Ignore auxiliary outputs during evaluation
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossy compression: {100 * correct / total}%')


# Load the Lossless dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossless', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained Inception v3 model and modify it for binary classification
model = models.inception_v3(pretrained=True)
# Handle the auxiliary net
aux_in_features = model.AuxLogits.fc.in_features
model.AuxLogits.fc = nn.Linear(aux_in_features, 2)
# Handle the primary net
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs, aux_outputs = model(inputs)  # Inception model outputs main and auxiliary outputs
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        loss = loss1 + 0.4 * loss2  # Combine losses
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)  # Ignore auxiliary outputs during evaluation
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossless compression: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:01<00:00, 74.3MB/s]
# Epoch 1, Loss: 1.298762321472168
# Epoch 2, Loss: 1.2461076974868774
# Epoch 3, Loss: 1.3747951984405518
# Epoch 4, Loss: 1.3496637344360352
# Epoch 5, Loss: 1.5059548616409302
# Epoch 6, Loss: 1.373117446899414
# Epoch 7, Loss: 1.5700569152832031
# Epoch 8, Loss: 1.9066927433013916
# Epoch 9, Loss: 0.9557609558105469
# Epoch 10, Loss: 1.1992303133010864
# Accuracy for Lossy compression: 51.0%
# Epoch 1, Loss: 1.0501750707626343
# Epoch 2, Loss: 0.7606610059738159
# Epoch 3, Loss: 0.9886097311973572
# Epoch 4, Loss: 1.229156732559204
# Epoch 5, Loss: 1.177396297454834
# Epoch 6, Loss: 1.1666433811187744
# Epoch 7, Loss: 1.5263028144836426
# Epoch 8, Loss: 1.1344751119613647
# Epoch 9, Loss: 1.4287185668945312
# Epoch 10, Loss: 1.1517153978347778
# Accuracy for Lossless compression: 53.0%

# %% [markdown]
# #### Vgg16 for Lossy vs Lossless comparison

# %%
# Load the Lossy dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossy', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained VGG16 model and modify it for binary classification
model = models.vgg16(pretrained=True)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 2)  # Modify the classifier layer

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossy compression: {100 * correct / total}%')

# Load the Lossless dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossless', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained VGG16 model and modify it for binary classification
model = models.vgg16(pretrained=True)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 2)  # Modify the classifier layer

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossless compression: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:07<00:00, 75.4MB/s]
# Epoch 1, Loss: 0.6346490383148193
# Epoch 2, Loss: 0.6492592096328735
# Epoch 3, Loss: 0.7108259201049805
# Epoch 4, Loss: 0.8579869270324707
# Epoch 5, Loss: 0.7502597570419312
# Epoch 6, Loss: 0.762658953666687
# Epoch 7, Loss: 0.7456668615341187
# Epoch 8, Loss: 0.7645624876022339
# Epoch 9, Loss: 0.6718744039535522
# Epoch 10, Loss: 0.6823136210441589
# Accuracy for Lossy compression: 44.0%
# Epoch 1, Loss: 0.7603607177734375
# Epoch 2, Loss: 0.7090679407119751
# Epoch 3, Loss: 0.7205440998077393
# Epoch 4, Loss: 0.7318661212921143
# Epoch 5, Loss: 0.6891897916793823
# Epoch 6, Loss: 0.6644810438156128
# Epoch 7, Loss: 0.7108893394470215
# Epoch 8, Loss: 0.6807684898376465
# Epoch 9, Loss: 0.6991374492645264
# Epoch 10, Loss: 0.7035802602767944
# Accuracy for Lossless compression: 51.0%

# %% [markdown]
# #### Custom Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

class AttentionModelBinary(models.Model):
    def __init__(self):
        super(AttentionModelBinary, self).__init__()

        # Define the backbone CNN (e.g., ResNet50 or VGG16)
        #self.backbone = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
        self.backbone = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

        # Global average pooling
        self.global_avg_pool = layers.GlobalAveragePooling2D()

        # Fully connected layer for attention mechanism
        self.attention_fc = layers.Dense(1, activation='sigmoid')

        # Fully connected layer for binary classification
        self.fc = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        # Backbone CNN
        x = self.backbone(inputs)

        # Global average pooling
        x = self.global_avg_pool(x)

        # Attention mechanism
        attention_weights = self.attention_fc(x)
        x = x * attention_weights

        # Binary classification
        x = self.fc(x)

        return x

# Instantiate the model
model_binary = AttentionModelBinary()

# Build the model
model_binary.build((None, 224, 224, 3))  # Specify input shape

# Compile the model
model_binary.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model_binary.summary()
# Out:
# Model: "attention_model_binary_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_1  multiple                  0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             multiple                  513
#
#  dense_3 (Dense)             multiple                  513
#
# =================================================================
# Total params: 14715714 (56.14 MB)
# Trainable params: 14715714 (56.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import InceptionV3

class AttentionModelBinary(models.Model):
    def __init__(self, num_attention_layers=3):
        super(AttentionModelBinary, self).__init__()

        # Define the backbone CNN (InceptionV3)
        self.backbone = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

        # Global average pooling
        self.global_avg_pool = layers.GlobalAveragePooling2D()

        # Fully connected layers for attention mechanism
        self.attention_fc_layers = [layers.Dense(1, activation='sigmoid') for _ in range(num_attention_layers)]

        # Fully connected layer for binary classification
        self.fc = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        # Backbone CNN
        x = self.backbone(inputs)

        # Global average pooling
        x = self.global_avg_pool(x)

        # Apply attention mechanism
        attention_weights = tf.ones_like(x)  # Initialize with uniform attention weights
        for attention_fc_layer in self.attention_fc_layers:
            attention_weights *= attention_fc_layer(x)
        x = x * attention_weights

        # Binary classification
        x = self.fc(x)

        return x

# Instantiate the model with InceptionV3 backbone
model_binary = AttentionModelBinary(num_attention_layers=3)

# Build the model
model_binary.build((None, 224, 224, 3))  # Specify input shape

# Compile the model
model_binary.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model_binary.summary()

import os
import random
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define directories
lossy_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossy'
lossless_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_compressed_lossless'

# Function to load and preprocess images
def load_images_from_directory(directory):
    images = []
    labels = []
    for filename in os.listdir(directory):
        img_path = os.path.join(directory, filename)
        img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        img_array /= 255.0  # Normalize pixel values
        images.append(img_array)
        labels.append(1 if 'tampered' in filename else 0)
    return np.array(images), np.array(labels)

# Load and preprocess images from both directories
images_lossy, labels_lossy = load_images_from_directory(lossy_dir)
images_lossless, labels_lossless = load_images_from_directory(lossless_dir)

# Split the data into training and testing sets (80-20 split) for both directories
train_images_lossy, test_images_lossy, train_labels_lossy, test_labels_lossy = train_test_split(images_lossy, labels_lossy, test_size=0.2, random_state=42)
train_images_lossless, test_images_lossless, train_labels_lossless, test_labels_lossless = train_test_split(images_lossless, labels_lossless, test_size=0.2, random_state=42)

# Define the model for lossy compression directory
model_lossy = AttentionModelBinary(num_attention_layers=3)
model_lossy.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_lossy.fit(train_images_lossy, train_labels_lossy, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set for lossy compression directory
lossy_test_loss, lossy_test_accuracy = model_lossy.evaluate(test_images_lossy, test_labels_lossy)

# Define the model for lossless compression directory
model_lossless = AttentionModelBinary(num_attention_layers=3)
model_lossless.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_lossless.fit(train_images_lossless, train_labels_lossless, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set for lossless compression directory
lossless_test_loss, lossless_test_accuracy = model_lossless.evaluate(test_images_lossless, test_labels_lossless)

# Print the final evaluation results
print("Lossy Compression Directory:")
print("Test Loss:", lossy_test_loss)
print("Test Accuracy:", lossy_test_accuracy)

print("\nLossless Compression Directory:")
print("Test Loss:", lossless_test_loss)
print("Test Accuracy:", lossless_test_accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "attention_model_binary_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d_1  multiple                  0
#  5 (GlobalAveragePooling2D)
#
#  dense_49 (Dense)            multiple                  2049
#
#  dense_50 (Dense)            multiple                  2049
#
#  dense_51 (Dense)            multiple                  2049
#
#  dense_52 (Dense)            multiple                  2049
#
# =================================================================
# Total params: 21810980 (83.20 MB)
# Trainable params: 21776548 (83.07 MB)
# Non-trainable params: 34432 (134.50 KB)
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 62s 21s/step - loss: 0.7216 - accuracy: 0.4219 - val_loss: 0.8033 - val_accuracy: 0.3125
# Epoch 2/10
# 2/2 [==============================] - 31s 16s/step - loss: 0.7412 - accuracy: 0.5469 - val_loss: 2.8622 - val_accuracy: 0.3750
# Epoch 3/10
# 2/2 [==============================] - 31s 16s/step - loss: 0.6694 - accuracy: 0.6406 - val_loss: 1.8213 - val_accuracy: 0.5000
# Epoch 4/10
# 2/2 [==============================] - 31s 16s/step - loss: 0.6044 - accuracy: 0.6094 - val_loss: 1.4155 - val_accuracy: 0.6250
# Epoch 5/10
# 2/2 [==============================] - 32s 17s/step - loss: 0.5824 - accuracy: 0.5781 - val_loss: 0.8031 - val_accuracy: 0.5625
# Epoch 6/10
# 2/2 [==============================] - 31s 16s/step - loss: 0.6572 - accuracy: 0.5938 - val_loss: 3.9829 - val_accuracy: 0.5000
# Epoch 7/10
# 2/2 [==============================] - 31s 16s/step - loss: 0.5897 - accuracy: 0.6094 - val_loss: 2.2660 - val_accuracy: 0.5000
# Epoch 8/10
# 2/2 [==============================] - 35s 18s/step - loss: 0.5944 - accuracy: 0.6250 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 9/10
# 2/2 [==============================] - 32s 17s/step - loss: 0.5573 - accuracy: 0.6250 - val_loss: 0.6971 - val_accuracy: 0.3750
# Epoch 10/10
# 2/2 [==============================] - 32s 17s/step - loss: 0.5735 - accuracy: 0.6094 - val_loss: 0.7004 - val_accuracy: 0.3750
# 1/1 [==============================] - 2s 2s/step - loss: 0.6778 - accuracy: 0.6000
# Epoch 1/10
# 2/2 [==============================] - 60s 19s/step - loss: 0.9062 - accuracy: 0.5469 - val_loss: 2.9865 - val_accuracy: 0.6250
# Epoch 2/10
# 2/2 [==============================] - 34s 19s/step - loss: 0.9406 - accuracy: 0.5469 - val_loss: 2.2533 - val_accuracy: 0.5625
# Epoch 3/10
# 2/2 [==============================] - 32s 17s/step - loss: 0.6742 - accuracy: 0.5469 - val_loss: 7.5320 - val_accuracy: 0.3750
# Epoch 4/10
# 2/2 [==============================] - 31s 16s/step - loss: 0.6477 - accuracy: 0.5312 - val_loss: 6.8304 - val_accuracy: 0.3750
# Epoch 5/10
# 2/2 [==============================] - 31s 16s/step - loss: 0.6091 - accuracy: 0.5625 - val_loss: 8.1769 - val_accuracy: 0.3750
# Epoch 6/10
# 2/2 [==============================] - 33s 17s/step - loss: 0.5914 - accuracy: 0.5625 - val_loss: 1.3392 - val_accuracy: 0.3750
# Epoch 7/10
# 2/2 [==============================] - 33s 18s/step - loss: 0.5748 - accuracy: 0.6250 - val_loss: 0.6731 - val_accuracy: 0.5625
# Epoch 8/10
# 2/2 [==============================] - 32s 17s/step - loss: 0.5707 - accuracy: 0.6406 - val_loss: 0.6904 - val_accuracy: 0.7500
# Epoch 9/10
# 2/2 [==============================] - 32s 17s/step - loss: 0.5637 - accuracy: 0.6562 - val_loss: 0.6671 - val_accuracy: 0.7500
# Epoch 10/10
# 2/2 [==============================] - 35s 17s/step - loss: 0.5751 - accuracy: 0.6094 - val_loss: 3.7608 - val_accuracy: 0.3750
# 1/1 [==============================] - 3s 3s/step - loss: 2.0460 - accuracy: 0.5500
# Lossy Compression Directory:
# Test Loss: 0.6778297424316406
# Test Accuracy: 0.6000000238418579
#
# Lossless Compression Directory:
# Test Loss: 2.0459957122802734
# Test Accuracy: 0.550000011920929

# %% [markdown]
# ### ResNET 50 for Unencoded

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.jpg')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/dataset/final_100', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained model and modify it for binary classification
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 129MB/s]
# Epoch 1, Loss: 0.4650789499282837
# Epoch 2, Loss: 1.0649558305740356
# Epoch 3, Loss: 0.723523736000061
# Epoch 4, Loss: 0.06531073898077011
# Epoch 5, Loss: 0.02765984646975994
# Epoch 6, Loss: 0.17586371302604675
# Epoch 7, Loss: 0.00044971986790187657
# Epoch 8, Loss: 0.008023645728826523
# Epoch 9, Loss: 0.5688663125038147
# Epoch 10, Loss: 0.014610407873988152
# Accuracy: 86.0%

# %% [markdown]
# ### Inception_v3

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.jpg')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations for Inception v3
transform = transforms.Compose([
    transforms.Resize(299),  # Resize so the smallest side is 299 pixels
    transforms.CenterCrop(299),  # Crop to 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/dataset/final_100', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained Inception v3 model and modify it for binary classification
model = models.inception_v3(pretrained=True)
# Handle the auxiliary net
aux_in_features = model.AuxLogits.fc.in_features
model.AuxLogits.fc = nn.Linear(aux_in_features, 2)
# Handle the primary net
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs, aux_outputs = model(inputs)  # Inception model outputs main and auxiliary outputs
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        loss = loss1 + 0.4 * loss2  # Combine losses
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)  # Ignore auxiliary outputs during evaluation
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1, Loss: 0.9562828540802002
# Epoch 2, Loss: 0.8443069458007812
# Epoch 3, Loss: 0.5874119400978088
# Epoch 4, Loss: 0.15629221498966217
# Epoch 5, Loss: 0.2857562005519867
# Epoch 6, Loss: 0.18358273804187775
# Epoch 7, Loss: 0.35113656520843506
# Epoch 8, Loss: 1.0960805416107178
# Epoch 9, Loss: 0.06464477628469467
# Epoch 10, Loss: 0.15823209285736084
# Accuracy: 96.0%

# %% [markdown]
# ### Vgg16

# %%
# Load the dataset
dataset = ImageDataset('/content/dataset/final_100', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained VGG16 model and modify it for binary classification
model = models.vgg16(pretrained=True)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 2)  # Modify the classifier layer

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# Epoch 1, Loss: 0.9754365682601929
# Epoch 2, Loss: 0.3820895850658417
# Epoch 3, Loss: 0.3209301233291626
# Epoch 4, Loss: 0.19768135249614716
# Epoch 5, Loss: 0.0044045704416930676
# Epoch 6, Loss: 0.22338804602622986
# Epoch 7, Loss: 0.24941523373126984
# Epoch 8, Loss: 0.22090715169906616
# Epoch 9, Loss: 0.0009937501745298505
# Epoch 10, Loss: 0.004270290955901146
# Accuracy: 100.0%

# %% [markdown]
# ### One word encoding

# %% [markdown]
# #### Encoded images with Tampering

# %%
import os
import random
import shutil
def copy_subset_images(source_dir, dest_dir, num_images):
    # Get a list of all files in the source directory
    files = os.listdir(source_dir)
    # Shuffle the list
    random.shuffle(files)
    # Take a subset of the shuffled list
    subset = files[:num_images]
    # Copy each file from the subset to the destination directory
    for filename in subset:
        shutil.copy(os.path.join(source_dir, filename), dest_dir)
img_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword'
if not os.path.exists(img_dir):
    os.makedirs(img_dir)
copy_subset_images('/content/dataset/ukraine_war_resized', img_dir, 50)

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import os
from PIL import Image
#Load pre-trained ResNet50 model
model = ResNet50(weights='imagenet')

def encode_image(img,message):
  def message_to_bin(message):
      binary = ''.join(format(ord(i), '08b') for i in message)
      return binary

  def modify_pixel(pixel, binary_message, index):
      if index < len(binary_message):
          pixel = (pixel & ~1) | int(binary_message[index])
      return pixel

  def enc_image(img, message):
      binary_message = message_to_bin(message) + '11111111'  # Delimiter to indicate end of message
      pixels = np.array(img)

      index = 0
      for i in range(pixels.shape[0]):
          for j in range(pixels.shape[1]):
              for k in range(3):  # Iterate over RGB channels
                  if index < len(binary_message):
                      pixels[i, j, k] = modify_pixel(pixels[i, j, k], binary_message, index)
                      index += 1

      encoded_img = Image.fromarray(pixels)
      return encoded_img
  return enc_image(img,message)


def decode_image(img):

    pixels = np.array(img)
    binary_message = ''
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            for k in range(3):
                binary_message += str(pixels[i, j, k] & 1)
                if binary_message[-8:] == '11111111':  # Check for delimiter
                    return ''.join(chr(int(binary_message[i:i+8], 2)) for i in range(0, len(binary_message)-8, 8))
    return None

# # Define the path to your dataset
dataset_path = img_dir

# Iterate through each image in the dataset
for filename in os.listdir(dataset_path):
    img_path = os.path.join(dataset_path, filename)
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    # Perform inference
    preds = model.predict(x)
    # Decode and print the top-3 predicted classes
    map = decode_predictions(preds, top=3)[0]
    print(f'Predicted for {filename}:', map[0][1])
    secret = f'{map[0][1]}'
    encoded_img = encode_image(img, secret)
    encoded_img.save(img_path.replace('jpg','png'))
    print("Decoded: ", decode_image(encoded_img))
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted for f44.jpg: amphibian
# Decoded:  amphibian
# 1/1 [==============================] - 0s 310ms/step
# Predicted for cf1.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 313ms/step
# Predicted for 3f4.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 329ms/step
# Predicted for 448.png.jpg: sliding_door
# Decoded:  sliding_door
# 1/1 [==============================] - 0s 329ms/step
# Predicted for 67.png.jpg: crane
# Decoded:  crane
# 1/1 [==============================] - 0s 304ms/step
# Predicted for tt6.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 356ms/step
# Predicted for Screenshot-8210.jpg: web_site
# Decoded:  web_site
# 1/1 [==============================] - 0s 336ms/step
# Predicted for 1245.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 350ms/step
# Predicted for 315.png.jpg: dam
# Decoded:  dam
# 1/1 [==============================] - 0s 349ms/step
# Predicted for 345.jpg: jeep
# Decoded:  jeep
# 1/1 [==============================] - 0s 293ms/step
# Predicted for b677.jpg: web_site
# Decoded:  web_site
# 1/1 [==============================] - 0s 341ms/step
# Predicted for 2f.jpg: tractor
# Decoded:  tractor
# 1/1 [==============================] - 0s 292ms/step
# Predicted for 3244.jpg: web_site
# Decoded:  web_site
# 1/1 [==============================] - 0s 372ms/step
# Predicted for 138.jpg: rifle
# Decoded:  rifle
# 1/1 [==============================] - 1s 527ms/step
# Predicted for h8.png.jpg: shoji
# Decoded:  shoji
# 1/1 [==============================] - 0s 413ms/step
# Predicted for q5.jpg: car_mirror
# Decoded:  car_mirror
# 1/1 [==============================] - 0s 487ms/step
# Predicted for 63.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 347ms/step
# Predicted for 32d.jpg: castle
# Decoded:  castle
# 1/1 [==============================] - 0s 264ms/step
# Predicted for 661.jpg: cannon
# Decoded:  cannon
# 1/1 [==============================] - 0s 205ms/step
# Predicted for 4f3.jpg: castle
# Decoded:  castle
# 1/1 [==============================] - 0s 223ms/step
# Predicted for 36p.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 204ms/step
# Predicted for Screenshot-8193.jpg: web_site
# Decoded:  web_site
# 1/1 [==============================] - 0s 202ms/step
# Predicted for 87.jpg.jpg: ashcan
# Decoded:  ashcan
# 1/1 [==============================] - 0s 199ms/step
# Predicted for 69.png.jpg: submarine
# Decoded:  submarine
# 1/1 [==============================] - 0s 211ms/step
# Predicted for Screenshot-8115.jpg: web_site
# Decoded:  web_site
# 1/1 [==============================] - 0s 210ms/step
# Predicted for g9.jpg.jpg: freight_car
# Decoded:  freight_car
# 1/1 [==============================] - 0s 215ms/step
# Predicted for 33213.jpg: shovel
# Decoded:  shovel
# 1/1 [==============================] - 0s 193ms/step
# Predicted for j76.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 211ms/step
# Predicted for d138.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 212ms/step
# Predicted for 4689.jpg: aircraft_carrier
# Decoded:  aircraft_carrier
# 1/1 [==============================] - 0s 207ms/step
# Predicted for 270.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 201ms/step
# Predicted for i2.jpg: hard_disc
# Decoded:  hard_disc
# 1/1 [==============================] - 0s 198ms/step
# Predicted for Screenshot-8275.jpg: web_site
# Decoded:  web_site
# 1/1 [==============================] - 0s 197ms/step
# Predicted for m4.png.jpg: military_uniform
# Decoded:  military_uniform
# 1/1 [==============================] - 0s 215ms/step
# Predicted for 18.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 189ms/step
# Predicted for 43111.png.jpg: doormat
# Decoded:  doormat
# 1/1 [==============================] - 0s 205ms/step
# Predicted for 6888.jpg: stove
# Decoded:  stove
# 1/1 [==============================] - 0s 194ms/step
# Predicted for r133.png.jpg: lakeside
# Decoded:  lakeside
# 1/1 [==============================] - 0s 207ms/step
# Predicted for 465.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 226ms/step
# Predicted for 5h.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 198ms/step
# Predicted for 6hd.jpg: amphibian
# Decoded:  amphibian
# 1/1 [==============================] - 0s 217ms/step
# Predicted for 331f.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 211ms/step
# Predicted for Screenshot-8343.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 208ms/step
# Predicted for zx3.jpg: half_track
# Decoded:  half_track
# 1/1 [==============================] - 0s 362ms/step
# Predicted for 678.jpg: snowplow
# Decoded:  snowplow
# 1/1 [==============================] - 0s 361ms/step
# Predicted for ttrr.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 351ms/step
# Predicted for e11.jpg: half_track
# Decoded:  half_track
# 1/1 [==============================] - 0s 339ms/step
# Predicted for 137.jpg: tank
# Decoded:  tank
# 1/1 [==============================] - 0s 351ms/step
# Predicted for r2.jpg.jpg: cliff
# Decoded:  cliff
# 1/1 [==============================] - 0s 246ms/step
# Predicted for Screenshot-8306.jpg: web_site
# Decoded:  web_site

# %%
import os

# Define the directory path
directory = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword'
files = os.listdir(directory)
# # Iterate over all files in the directory
# for filename in os.listdir(directory):
#     # Check if the file has a .jpg extension
#     if filename.endswith(".jpg"):
#         # Construct the full file path
#         file_path = os.path.join(directory, filename)
#         # Remove the file
#         os.remove(file_path)
#         print("Removed:", file_path)

# print("All .jpg files removed from the directory.")

tampered_count = sum('tampered' in filename for filename in files)

print("Number of files with 'tampered' in their name:", tampered_count)

print("Number of files with no 'tampered' in their name:", sum('tampered' not in filename for filename in files))
# Out:
# Number of files with 'tampered' in their name: 50
# Number of files with no 'tampered' in their name: 50

# %%
from PIL import Image
def decode_image(img):

    pixels = np.array(img)
    binary_message = ''
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            for k in range(3):
                binary_message += str(pixels[i, j, k] & 1)
                if binary_message[-8:] == '11111111':  # Check for delimiter
                    return ''.join(chr(int(binary_message[i:i+8], 2)) for i in range(0, len(binary_message)-8, 8))
    return None

decode_image(Image.open(directory+'_compressed_lossy/q5.png')) #['87.jpg.png', 'g9.jpg.png', 'r2.jpg.png']
# Out:
# 'TOPSECRET: This is the shower_curtain.'

# %%
import os

tamp = [filename.replace('_tampered','') for filename in files if 'tampered' in filename]
non_tamp = [filename for filename in files if 'tampered' not in filename ]

# Find the difference between the two lists
difference = list(set(tamp) - set(non_tamp))

# Display the filenames that are unique to the second directory
print("Files unique to the second directory:")
print(difference)

tamp = ['87.jpg_tampered.png', 'g9.jpg_tampered.png', 'r2.jpg_tampered.png']
for filename in os.listdir(directory):
    # Check if the file has a .jpg extension
    if filename in tamp:
        # Construct the full file path
        file_path = os.path.join(directory, filename)
        # Remove the file
        os.remove(file_path)
        print("Removed:", file_path)
# Out:
# Files unique to the second directory:
# ['87.jpg.png', 'g9.jpg.png', 'r2.jpg.png']
# Removed: /content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword/87.jpg_tampered.png
# Removed: /content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword/g9.jpg_tampered.png
# Removed: /content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword/r2.jpg_tampered.png

# %%
from PIL import Image
import numpy as np


def add_noise(img, mean=0, var=0.01):
    """ Add Gaussian noise to an image. """
    row, col, ch = img.shape
    sigma = var**0.5
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    gauss = gauss.reshape(row, col, ch)
    noisy = img + gauss
    return np.clip(noisy, 0, 255).astype(np.uint8)

def decode_image(img):

    pixels = np.array(img)
    binary_message = ''
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            for k in range(3):
                binary_message += str(pixels[i, j, k] & 1)
                if binary_message[-8:] == '11111111':  # Check for delimiter
                    return ''.join(chr(int(binary_message[i:i+8], 2)) for i in range(0, len(binary_message)-8, 8))
    return None

def tamper_image(img, save_path='tampered_image.png'):
    img = np.array(img)

    # Optionally add noise
    img = add_noise(img)

    # Optionally crop the image (specify the crop area)
    #img = crop_image(img, 50, 50, 200, 200)  # Adjust these values based on your image dimensions

    # Convert back to PIL Image to rotate
    img = Image.fromarray(img)
    #img = rotate_image(img, 45)  # Rotate by 45 degrees
    return img


#encoded_image = encode_image('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50/312.png', 'YourSecretCode123')
tamper_image = tamper_image(Image.open('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword/137.png'))

decoded_message = decode_image(tamper_image)
print(decoded_message)
# Out:
#  z"À¢÷HC»n0ß§¼Ú$ª²m²á¨ü

# %% [markdown]
# #### Tamper Encoded Data - Encoded_50

# %%
def tamper_images_data(image_dir, output_dir, target_size=(224, 224)):
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    count = 0
    # Iterate through each image in the directory
    for filename in os.listdir(image_dir):
        if count==1400:
          break
        img_path = os.path.join(image_dir, filename)
        try:

            img = tamper_image_path(img_path)

            # Save the image as JPG format
            output_path = os.path.join(output_dir, os.path.splitext(filename)[0] + '_tampered.png')
            img.save(output_path)

            print(f"Image '{img_path}' tampered successfully.")
            count+=1
        except Exception as e:
            print(f"Error processing image '{img_path}': {e}")

def tamper_image_path(img_path, save_path='tampered_image.png'):
    img = Image.open(img_path)
    img = np.array(img)

    # Optionally add noise
    img = add_noise(img)

    # Optionally crop the image (specify the crop area)
    #img = crop_image(img, 50, 50, 200, 200)  # Adjust these values based on your image dimensions

    # Convert back to PIL Image to rotate
    img = Image.fromarray(img)
    #img = rotate_image(img, 45)  # Rotate by 45 degrees

    return img
tamper_images_data('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword', '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword')

# %% [markdown]
# #### ResNet

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained model and modify it for binary classification
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 55.5MB/s]
# Epoch 1, Loss: 0.8432307243347168
# Epoch 2, Loss: 0.9920649528503418
# Epoch 3, Loss: 0.6854563355445862
# Epoch 4, Loss: 0.951202392578125
# Epoch 5, Loss: 0.7416930198669434
# Epoch 6, Loss: 1.3178246021270752
# Epoch 7, Loss: 0.5595020651817322
# Epoch 8, Loss: 0.6704518795013428
# Epoch 9, Loss: 0.7183675169944763
# Epoch 10, Loss: 1.091508388519287
# Accuracy: 52.0%

# %% [markdown]
# #### Inception_v3

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations for Inception v3
transform = transforms.Compose([
    transforms.Resize(299),  # Resize so the smallest side is 299 pixels
    transforms.CenterCrop(299),  # Crop to 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained Inception v3 model and modify it for binary classification
model = models.inception_v3(pretrained=True)
# Handle the auxiliary net
aux_in_features = model.AuxLogits.fc.in_features
model.AuxLogits.fc = nn.Linear(aux_in_features, 2)
# Handle the primary net
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs, aux_outputs = model(inputs)  # Inception model outputs main and auxiliary outputs
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        loss = loss1 + 0.4 * loss2  # Combine losses
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)  # Ignore auxiliary outputs during evaluation
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:02<00:00, 50.9MB/s]
# Epoch 1, Loss: 0.9817787408828735
# Epoch 2, Loss: 0.5946680307388306
# Epoch 3, Loss: 1.335357904434204
# Epoch 4, Loss: 1.383239507675171
# Epoch 5, Loss: 1.4236304759979248
# Epoch 6, Loss: 1.5762196779251099
# Epoch 7, Loss: 1.1635208129882812
# Epoch 8, Loss: 1.8531454801559448
# Epoch 9, Loss: 1.2547552585601807
# Epoch 10, Loss: 0.9226182699203491
# Accuracy: 53.0%

# %% [markdown]
# #### Vgg16

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations for Inception v3
transform = transforms.Compose([
    transforms.Resize(299),  # Resize so the smallest side is 299 pixels
    transforms.CenterCrop(299),  # Crop to 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
# Load the dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained VGG16 model and modify it for binary classification
model = models.vgg16(pretrained=True)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 2)  # Modify the classifier layer

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:11<00:00, 46.5MB/s]
# Epoch 1, Loss: 0.6943711042404175
# Epoch 2, Loss: 0.846409261226654
# Epoch 3, Loss: 0.8235284090042114
# Epoch 4, Loss: 0.6714967489242554
# Epoch 5, Loss: 0.6478991508483887
# Epoch 6, Loss: 0.6876139640808105
# Epoch 7, Loss: 0.7275097370147705
# Epoch 8, Loss: 0.7205191254615784
# Epoch 9, Loss: 0.7313621044158936
# Epoch 10, Loss: 0.7148164510726929
# Accuracy: 38.0%

# %% [markdown]
# #### Encoded and compressed images with Tampering

# %% [markdown]
# #### Lossy and Lossless compression- Encoded_50_compressed Lossy/Lossless

# %%
import os
from PIL import Image

# Define source directory
source_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword'

# Define destination directories for lossy and lossless compression
destination_lossy = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossy'
destination_lossless = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossless'

# Create destination directories if they don't exist
os.makedirs(destination_lossy, exist_ok=True)
os.makedirs(destination_lossless, exist_ok=True)

# Iterate over files in the source directory
for filename in os.listdir(source_dir):
    # Check if the filename does not contain 'tampered'
    if 'tampered' not in filename:
        # Construct the full path of the source file
        source_file = os.path.join(source_dir, filename)

        # Open the image
        img = Image.open(source_file)

        # Save the image with lossy compression
        img.save(os.path.join(destination_lossy, filename), quality=80)  # Adjust quality as needed

        # Save the image with lossless compression
        img.save(os.path.join(destination_lossless, filename), format='PNG')

print("Images moved and compressed successfully.")
# Out:
# Images moved and compressed successfully.

# %% [markdown]
# #### Tamper Encoded+Compressed Data

# %%
def add_noise(img, mean=0, var=0.01):
    """ Add Gaussian noise to an image. """
    row, col, ch = img.shape
    sigma = var**0.5
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    gauss = gauss.reshape(row, col, ch)
    noisy = img + gauss
    return np.clip(noisy, 0, 255).astype(np.uint8)
tamper_images_data('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossy', '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossy')

tamper_images_data('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossless', '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossless')

# %% [markdown]
# #### ResNet for Lossy vs Lossless compression

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the Lossy dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossy', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained model and modify it for binary classification
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossy compression: {100 * correct / total}%')


# Load the Lossless dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossless', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained model and modify it for binary classification
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossless compression: {100 * correct / total}%')
# Out:
# Epoch 1, Loss: 0.8541858196258545
# Epoch 2, Loss: 0.8212792277336121
# Epoch 3, Loss: 0.7064712643623352
# Epoch 4, Loss: 1.1609654426574707
# Epoch 5, Loss: 2.016200542449951
# Epoch 6, Loss: 0.8550192713737488
# Epoch 7, Loss: 0.7118191719055176
# Epoch 8, Loss: 0.8996041417121887
# Epoch 9, Loss: 0.8642978072166443
# Epoch 10, Loss: 0.9214853048324585
# Accuracy for Lossy compression: 53.0%
# Epoch 1, Loss: 0.7564785480499268
# Epoch 2, Loss: 0.5957449674606323
# Epoch 3, Loss: 0.9970687627792358
# Epoch 4, Loss: 2.2219889163970947
# Epoch 5, Loss: 0.972685694694519
# Epoch 6, Loss: 0.8285111784934998
# Epoch 7, Loss: 0.9164414405822754
# Epoch 8, Loss: 0.718784749507904
# Epoch 9, Loss: 0.6306334733963013
# Epoch 10, Loss: 1.019258737564087
# Accuracy for Lossless compression: 50.0%

# %% [markdown]
# #### Inception_v3 for Lossy vs Lossless comparison

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations for Inception v3
transform = transforms.Compose([
    transforms.Resize(299),  # Resize so the smallest side is 299 pixels
    transforms.CenterCrop(299),  # Crop to 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the Lossy dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossy', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained Inception v3 model and modify it for binary classification
model = models.inception_v3(pretrained=True)
# Handle the auxiliary net
aux_in_features = model.AuxLogits.fc.in_features
model.AuxLogits.fc = nn.Linear(aux_in_features, 2)
# Handle the primary net
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs, aux_outputs = model(inputs)  # Inception model outputs main and auxiliary outputs
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        loss = loss1 + 0.4 * loss2  # Combine losses
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)  # Ignore auxiliary outputs during evaluation
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossy compression: {100 * correct / total}%')


# Load the Lossless dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossless', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained Inception v3 model and modify it for binary classification
model = models.inception_v3(pretrained=True)
# Handle the auxiliary net
aux_in_features = model.AuxLogits.fc.in_features
model.AuxLogits.fc = nn.Linear(aux_in_features, 2)
# Handle the primary net
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs, aux_outputs = model(inputs)  # Inception model outputs main and auxiliary outputs
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        loss = loss1 + 0.4 * loss2  # Combine losses
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)  # Ignore auxiliary outputs during evaluation
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossless compression: {100 * correct / total}%')
# Out:
# Epoch 1, Loss: 0.9786534905433655
# Epoch 2, Loss: 1.2571442127227783
# Epoch 3, Loss: 1.2017606496810913
# Epoch 4, Loss: 0.9589161276817322
# Epoch 5, Loss: 1.9287937879562378
# Epoch 6, Loss: 1.999070167541504
# Epoch 7, Loss: 1.178396463394165
# Epoch 8, Loss: 1.2994167804718018
# Epoch 9, Loss: 1.7306805849075317
# Epoch 10, Loss: 0.8934602737426758
# Accuracy for Lossy compression: 52.0%
# Epoch 1, Loss: 1.6257514953613281
# Epoch 2, Loss: 1.433807373046875
# Epoch 3, Loss: 1.1729583740234375
# Epoch 4, Loss: 2.1413962841033936
# Epoch 5, Loss: 1.7241374254226685
# Epoch 6, Loss: 0.8155306577682495
# Epoch 7, Loss: 1.5011794567108154
# Epoch 8, Loss: 0.8747657537460327
# Epoch 9, Loss: 1.2186756134033203
# Epoch 10, Loss: 2.0634875297546387
# Accuracy for Lossless compression: 50.0%

# %% [markdown]
# #### Vgg16 for Lossy vs Lossless comparison

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img = Image.open(img_name).convert('RGB')
        label = 1 if 'tampered' in img_name else 0
        if self.transform:
            img = self.transform(img)
        return img, label

# Transformations for Inception v3
transform = transforms.Compose([
    transforms.Resize(299),  # Resize so the smallest side is 299 pixels
    transforms.CenterCrop(299),  # Crop to 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the Lossy dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossy', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained VGG16 model and modify it for binary classification
model = models.vgg16(pretrained=True)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 2)  # Modify the classifier layer

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossy compression: {100 * correct / total}%')

# Load the Lossless dataset
dataset = ImageDataset('/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossless', transform=transform)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Load a pretrained VGG16 model and modify it for binary classification
model = models.vgg16(pretrained=True)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 2)  # Modify the classifier layer

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluation
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in train_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy for Lossless compression: {100 * correct / total}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:04<00:00, 118MB/s]
# Epoch 1, Loss: 0.8195719122886658
# Epoch 2, Loss: 0.7445290088653564
# Epoch 3, Loss: 0.6903973817825317
# Epoch 4, Loss: 0.6800094842910767
# Epoch 5, Loss: 0.7246004939079285
# Epoch 6, Loss: 0.7679092288017273
# Epoch 7, Loss: 0.7661856412887573
# Epoch 8, Loss: 0.6967925429344177
# Epoch 9, Loss: 0.7379640340805054
# Epoch 10, Loss: 0.7432527542114258
# Accuracy for Lossy compression: 53.0%
# Epoch 1, Loss: 0.8317618370056152
# Epoch 2, Loss: 0.8385272026062012
# Epoch 3, Loss: 0.9268648624420166
# Epoch 4, Loss: 0.6916348338127136
# Epoch 5, Loss: 0.7285965085029602
# Epoch 6, Loss: 0.720246434211731
# Epoch 7, Loss: 0.7548275589942932
# Epoch 8, Loss: 0.6877894401550293
# Epoch 9, Loss: 0.6800702810287476
# Epoch 10, Loss: 0.7380979061126709
# Accuracy for Lossless compression: 51.0%

# %% [markdown]
# #### Custom Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import InceptionV3

class AttentionModelBinary(models.Model):
    def __init__(self, num_attention_layers=3):
        super(AttentionModelBinary, self).__init__()

        # Define the backbone CNN (InceptionV3)
        self.backbone = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

        # Global average pooling
        self.global_avg_pool = layers.GlobalAveragePooling2D()

        # Fully connected layers for attention mechanism
        self.attention_fc_layers = [layers.Dense(1, activation='sigmoid') for _ in range(num_attention_layers)]

        # Fully connected layer for binary classification
        self.fc = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        # Backbone CNN
        x = self.backbone(inputs)

        # Global average pooling
        x = self.global_avg_pool(x)

        # Apply attention mechanism
        attention_weights = tf.ones_like(x)  # Initialize with uniform attention weights
        for attention_fc_layer in self.attention_fc_layers:
            attention_weights *= attention_fc_layer(x)
        x = x * attention_weights

        # Binary classification
        x = self.fc(x)

        return x

# Instantiate the model with InceptionV3 backbone
model_binary = AttentionModelBinary(num_attention_layers=3)

# Build the model
model_binary.build((None, 224, 224, 3))  # Specify input shape

# Compile the model
model_binary.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model_binary.summary()

import os
import random
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define directories
lossy_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossy'
lossless_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossless'

# Function to load and preprocess images
def load_images_from_directory(directory):
    images = []
    labels = []
    for filename in os.listdir(directory):
        img_path = os.path.join(directory, filename)
        img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        img_array /= 255.0  # Normalize pixel values
        images.append(img_array)
        labels.append(1 if 'tampered' in filename else 0)
    return np.array(images), np.array(labels)

# Load and preprocess images from both directories
images_lossy, labels_lossy = load_images_from_directory(lossy_dir)
images_lossless, labels_lossless = load_images_from_directory(lossless_dir)

# Split the data into training and testing sets (80-20 split) for both directories
train_images_lossy, test_images_lossy, train_labels_lossy, test_labels_lossy = train_test_split(images_lossy, labels_lossy, test_size=0.2, random_state=42)
train_images_lossless, test_images_lossless, train_labels_lossless, test_labels_lossless = train_test_split(images_lossless, labels_lossless, test_size=0.2, random_state=42)

# Define the model for lossy compression directory
model_lossy = AttentionModelBinary(num_attention_layers=3)
model_lossy.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_lossy.fit(train_images_lossy, train_labels_lossy, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set for lossy compression directory
lossy_test_loss, lossy_test_accuracy = model_lossy.evaluate(test_images_lossy, test_labels_lossy)

# Define the model for lossless compression directory
model_lossless = AttentionModelBinary(num_attention_layers=3)
model_lossless.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_lossless.fit(train_images_lossless, train_labels_lossless, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set for lossless compression directory
lossless_test_loss, lossless_test_accuracy = model_lossless.evaluate(test_images_lossless, test_labels_lossless)

# Print the final evaluation results
print("Lossy Compression Directory:")
print("Test Loss:", lossy_test_loss)
print("Test Accuracy:", lossy_test_accuracy)

print("\nLossless Compression Directory:")
print("Test Loss:", lossless_test_loss)
print("Test Accuracy:", lossless_test_accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "attention_model_binary"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d (  multiple                  0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               multiple                  2049
#
#  dense_1 (Dense)             multiple                  2049
#
#  dense_2 (Dense)             multiple                  2049
#
#  dense_3 (Dense)             multiple                  2049
#
# =================================================================
# Total params: 21810980 (83.20 MB)
# Trainable params: 21776548 (83.07 MB)
# Non-trainable params: 34432 (134.50 KB)
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 72s 21s/step - loss: 0.7495 - accuracy: 0.4375 - val_loss: 1.0084 - val_accuracy: 0.3750
# Epoch 2/10
# 2/2 [==============================] - 33s 18s/step - loss: 0.6912 - accuracy: 0.5625 - val_loss: 1.1535 - val_accuracy: 0.3750
# Epoch 3/10
# 2/2 [==============================] - 34s 18s/step - loss: 0.6543 - accuracy: 0.6094 - val_loss: 1.5408 - val_accuracy: 0.3750
# Epoch 4/10
# 2/2 [==============================] - 34s 18s/step - loss: 0.6211 - accuracy: 0.5938 - val_loss: 5.3657 - val_accuracy: 0.3750
# Epoch 5/10
# 2/2 [==============================] - 33s 17s/step - loss: 0.6026 - accuracy: 0.6250 - val_loss: 17.2952 - val_accuracy: 0.3750
# Epoch 6/10
# 2/2 [==============================] - 35s 18s/step - loss: 0.5973 - accuracy: 0.5938 - val_loss: 32.8199 - val_accuracy: 0.3750
# Epoch 7/10
# 2/2 [==============================] - 33s 17s/step - loss: 0.5662 - accuracy: 0.6250 - val_loss: 64.5151 - val_accuracy: 0.3750
# Epoch 8/10
# 2/2 [==============================] - 34s 18s/step - loss: 0.7980 - accuracy: 0.5781 - val_loss: 1.9915 - val_accuracy: 0.5625
# Epoch 9/10
# 2/2 [==============================] - 34s 18s/step - loss: 0.5959 - accuracy: 0.6094 - val_loss: 0.6928 - val_accuracy: 0.6250
# Epoch 10/10
# 2/2 [==============================] - 33s 17s/step - loss: 0.6870 - accuracy: 0.6094 - val_loss: 0.6928 - val_accuracy: 0.6250
# 1/1 [==============================] - 2s 2s/step - loss: 0.6935 - accuracy: 0.4000
# Epoch 1/10
# 2/2 [==============================] - 58s 20s/step - loss: 0.8349 - accuracy: 0.4375 - val_loss: 2.8754 - val_accuracy: 0.5625
# Epoch 2/10
# 2/2 [==============================] - 34s 18s/step - loss: 0.8846 - accuracy: 0.6250 - val_loss: 0.6964 - val_accuracy: 0.5625
# Epoch 3/10
# 2/2 [==============================] - 33s 17s/step - loss: 0.6620 - accuracy: 0.5312 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 4/10
# 2/2 [==============================] - 37s 18s/step - loss: 0.5960 - accuracy: 0.6250 - val_loss: 0.8208 - val_accuracy: 0.6250
# Epoch 5/10
# 2/2 [==============================] - 33s 17s/step - loss: 0.5869 - accuracy: 0.6250 - val_loss: 5.0875 - val_accuracy: 0.5000
# Epoch 6/10
# 2/2 [==============================] - 33s 18s/step - loss: 0.5766 - accuracy: 0.5625 - val_loss: 5.7286 - val_accuracy: 0.4375
# Epoch 7/10
# 2/2 [==============================] - 34s 19s/step - loss: 0.5742 - accuracy: 0.5625 - val_loss: 3.7840 - val_accuracy: 0.4375
# Epoch 8/10
# 2/2 [==============================] - 34s 18s/step - loss: 0.5765 - accuracy: 0.5938 - val_loss: 7.0355 - val_accuracy: 0.4375
# Epoch 9/10
# 2/2 [==============================] - 36s 21s/step - loss: 0.5732 - accuracy: 0.5625 - val_loss: 4.3976 - val_accuracy: 0.4375
# Epoch 10/10
# 2/2 [==============================] - 34s 18s/step - loss: 0.6293 - accuracy: 0.5469 - val_loss: 2.2224 - val_accuracy: 0.5000
# 1/1 [==============================] - 2s 2s/step - loss: 1.6484 - accuracy: 0.4500
# Lossy Compression Directory:
# Test Loss: 0.6934670209884644
# Test Accuracy: 0.4000000059604645
#
# Lossless Compression Directory:
# Test Loss: 1.6483852863311768
# Test Accuracy: 0.44999998807907104

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import InceptionV3

class AttentionModelBinary(models.Model):
    def __init__(self, num_attention_layers=3):
        super(AttentionModelBinary, self).__init__()

        # Define the backbone CNN (InceptionV3)
        self.backbone = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

        # Global average pooling
        self.global_avg_pool = layers.GlobalAveragePooling2D()

        # Fully connected layers for attention mechanism
        self.attention_fc_layers = [layers.Dense(1, activation='sigmoid') for _ in range(num_attention_layers)]

        # Fully connected layer for binary classification
        self.fc = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        # Backbone CNN
        x = self.backbone(inputs)

        # Global average pooling
        x = self.global_avg_pool(x)

        # Apply attention mechanism
        attention_weights = tf.ones_like(x)  # Initialize with uniform attention weights
        for attention_fc_layer in self.attention_fc_layers:
            attention_weights *= attention_fc_layer(x)
        x = x * attention_weights

        # Binary classification
        x = self.fc(x)

        return x

# Instantiate the model with InceptionV3 backbone
model_binary = AttentionModelBinary(num_attention_layers=3)

# Build the model
model_binary.build((None, 224, 224, 3))  # Specify input shape

# Compile the model
model_binary.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model_binary.summary()

import os
import random
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define directories
lossy_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossy'
lossless_dir = '/content/drive/MyDrive/Courses/Sem 2/DL/encoded_50_oneword_compressed_lossless'

# Function to load and preprocess images
def load_images_from_directory(directory):
    images = []
    labels = []
    for filename in os.listdir(directory):
        img_path = os.path.join(directory, filename)
        img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        img_array /= 255.0  # Normalize pixel values
        images.append(img_array)
        labels.append(1 if 'tampered' in filename else 0)
    return np.array(images), np.array(labels)

# Load and preprocess images from both directories
images_lossy, labels_lossy = load_images_from_directory(lossy_dir)
images_lossless, labels_lossless = load_images_from_directory(lossless_dir)

# Split the data into training and testing sets (80-20 split) for both directories
train_images_lossy, test_images_lossy, train_labels_lossy, test_labels_lossy = train_test_split(images_lossy, labels_lossy, test_size=0.2, random_state=42)
train_images_lossless, test_images_lossless, train_labels_lossless, test_labels_lossless = train_test_split(images_lossless, labels_lossless, test_size=0.2, random_state=42)

# Define the model for lossy compression directory
model_lossy = AttentionModelBinary(num_attention_layers=3)
model_lossy.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_lossy.fit(train_images_lossy, train_labels_lossy, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set for lossy compression directory
lossy_test_loss, lossy_test_accuracy = model_lossy.evaluate(test_images_lossy, test_labels_lossy)

# Define the model for lossless compression directory
model_lossless = AttentionModelBinary(num_attention_layers=3)
model_lossless.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_lossless.fit(train_images_lossless, train_labels_lossless, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set for lossless compression directory
lossless_test_loss, lossless_test_accuracy = model_lossless.evaluate(test_images_lossless, test_labels_lossless)

# Print the final evaluation results
print("Lossy Compression Directory:")
print("Test Loss:", lossy_test_loss)
print("Test Accuracy:", lossy_test_accuracy)

print("\nLossless Compression Directory:")
print("Test Loss:", lossless_test_loss)
print("Test Accuracy:", lossless_test_accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "attention_model_binary"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d (  multiple                  0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               multiple                  2049
#
#  dense_1 (Dense)             multiple                  2049
#
#  dense_2 (Dense)             multiple                  2049
#
#  dense_3 (Dense)             multiple                  2049
#
# =================================================================
# Total params: 21810980 (83.20 MB)
# Trainable params: 21776548 (83.07 MB)
# Non-trainable params: 34432 (134.50 KB)
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 83s 22s/step - loss: 0.8498 - accuracy: 0.3906 - val_loss: 1.1556 - val_accuracy: 0.4375
# Epoch 2/10
# 2/2 [==============================] - 41s 23s/step - loss: 0.8091 - accuracy: 0.6094 - val_loss: 2.9730 - val_accuracy: 0.3750
# Epoch 3/10
# 2/2 [==============================] - 41s 21s/step - loss: 0.6683 - accuracy: 0.5938 - val_loss: 3.8447 - val_accuracy: 0.3125
# Epoch 4/10
# 2/2 [==============================] - 41s 21s/step - loss: 0.6372 - accuracy: 0.5781 - val_loss: 5.4831 - val_accuracy: 0.3125
# Epoch 5/10
# 2/2 [==============================] - 41s 22s/step - loss: 0.6105 - accuracy: 0.5938 - val_loss: 10.7190 - val_accuracy: 0.3125
# Epoch 6/10
# 2/2 [==============================] - 42s 22s/step - loss: 0.5833 - accuracy: 0.5625 - val_loss: 11.2218 - val_accuracy: 0.3125
# Epoch 7/10
# 2/2 [==============================] - 40s 21s/step - loss: 0.5780 - accuracy: 0.5938 - val_loss: 10.9855 - val_accuracy: 0.3750
# Epoch 8/10
# 2/2 [==============================] - 40s 21s/step - loss: 0.5616 - accuracy: 0.5938 - val_loss: 9.7162 - val_accuracy: 0.4375
# Epoch 9/10
# 2/2 [==============================] - 45s 25s/step - loss: 0.8340 - accuracy: 0.5625 - val_loss: 44.9685 - val_accuracy: 0.6250
# Epoch 10/10
# 2/2 [==============================] - 39s 20s/step - loss: 0.6666 - accuracy: 0.5781 - val_loss: 49.8080 - val_accuracy: 0.6250
# 1/1 [==============================] - 3s 3s/step - loss: 62.3885 - accuracy: 0.4000
# Epoch 1/10
# 2/2 [==============================] - 73s 23s/step - loss: 0.7617 - accuracy: 0.3750 - val_loss: 1.1691 - val_accuracy: 0.4375
# Epoch 2/10
# 2/2 [==============================] - 44s 25s/step - loss: 0.8169 - accuracy: 0.5312 - val_loss: 2.6215 - val_accuracy: 0.3750
# Epoch 3/10
# 2/2 [==============================] - 40s 20s/step - loss: 0.7043 - accuracy: 0.5781 - val_loss: 1.5110 - val_accuracy: 0.6250
# Epoch 4/10
# 2/2 [==============================] - 37s 19s/step - loss: 0.7289 - accuracy: 0.5156 - val_loss: 2.2780 - val_accuracy: 0.5625
# Epoch 5/10
# 2/2 [==============================] - 41s 23s/step - loss: 0.6535 - accuracy: 0.5312 - val_loss: 1.1726 - val_accuracy: 0.6250
# Epoch 6/10
# 2/2 [==============================] - 37s 19s/step - loss: 0.6357 - accuracy: 0.5156 - val_loss: 0.8767 - val_accuracy: 0.6250
# Epoch 7/10
# 2/2 [==============================] - 37s 19s/step - loss: 0.6392 - accuracy: 0.5000 - val_loss: 0.6727 - val_accuracy: 0.6250
# Epoch 8/10
# 2/2 [==============================] - 39s 21s/step - loss: 0.7138 - accuracy: 0.5000 - val_loss: 0.6893 - val_accuracy: 0.6250
# Epoch 9/10
# 2/2 [==============================] - 42s 23s/step - loss: 0.6770 - accuracy: 0.5000 - val_loss: 0.6930 - val_accuracy: 0.6250
# Epoch 10/10
# 2/2 [==============================] - 38s 20s/step - loss: 0.6876 - accuracy: 0.5625 - val_loss: 0.6928 - val_accuracy: 0.6250
# 1/1 [==============================] - 3s 3s/step - loss: 0.6934 - accuracy: 0.4000
# Lossy Compression Directory:
# Test Loss: 62.38847732543945
# Test Accuracy: 0.4000000059604645
#
# Lossless Compression Directory:
# Test Loss: 0.6934484243392944
# Test Accuracy: 0.4000000059604645
